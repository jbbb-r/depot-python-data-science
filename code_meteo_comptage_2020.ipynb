# %%
import pandas as pd

# %%
df20 = pd.read_csv("data/2020_comptage-velo-donnees-sites-comptage.csv", on_bad_lines='skip')
df20.head()
# Out:
#                                                     Identifiant du point de comptage;Nom du point de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du point de comptage;Lien vers photo du point de comptage;Coordonnées géographiques
# 100044495;7 avenue de la Grande Armée NO-SE;5;2...                                            2.29215
# 100044495;7 avenue de la Grande Armée NO-SE;3;2...                                            2.29215
# 100044495;7 avenue de la Grande Armée NO-SE;2;2...                                            2.29215
# 100044495;7 avenue de la Grande Armée NO-SE;8;2...                                            2.29215
# 100044495;7 avenue de la Grande Armée NO-SE;0;2...                                            2.29215

# %%
list(df20.columns)
# Out:
# ["Identifiant du point de comptage;Nom du point de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du point de comptage;Lien vers photo du point de comptage;Coordonnées géographiques"]

# %%
colsToKeep = [
    # 'Identifiant du point de comptage',
    'Nom du point de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    # 'Date d'installation du point de comptage',
    #'Lien vers photo du point de comptage',
    'Coordonnées géographiques',
]
df20 = pd.read_csv("data/2020_comptage-velo-donnees-sites-comptage.csv", sep=";", usecols=colsToKeep, on_bad_lines='skip')
df20.head()
# Out:
#             Nom du point de comptage  Comptage horaire  \
# 0  7 avenue de la Grande Armée NO-SE                 5
# 1  7 avenue de la Grande Armée NO-SE                 3
# 2  7 avenue de la Grande Armée NO-SE                 2
# 3  7 avenue de la Grande Armée NO-SE                 8
# 4  7 avenue de la Grande Armée NO-SE                 0
#
#    Date et heure de comptage Coordonnées géographiques
# 0  2020-12-28T05:45:00+01:00          48.87451,2.29215
# 1  2020-12-28T13:00:00+01:00          48.87451,2.29215
# 2  2020-12-28T21:45:00+01:00          48.87451,2.29215
# 3  2020-12-29T08:30:00+01:00          48.87451,2.29215
# 4  2020-12-30T02:30:00+01:00          48.87451,2.29215

# %%
df20.shape
# Out:
# (2314738, 4)

# %%
df20[['latitude', 'longitude']] = df20['Coordonnées géographiques'].str.split(',', n=1, expand=True)

df20["Date et heure de comptage"] = pd.to_datetime(
    df20["Date et heure de comptage"], 
    utc=True,    # rend les dates tz‑aware (UTC)
    errors='coerce'
)

# %%
df20_sortedbyplace = df20.sort_values(by=["Nom du point de comptage","Date et heure de comptage"])
df20_sortedbyplace.head()
# Out:
#                    Nom du point de comptage  Comptage horaire  \
# 1402541  10 avenue de la Grande Armée SE-NO                 0
# 674837   10 avenue de la Grande Armée SE-NO                 0
# 344303   10 avenue de la Grande Armée SE-NO                 0
# 1252771  10 avenue de la Grande Armée SE-NO                 0
# 20673    10 avenue de la Grande Armée SE-NO                 1
#
#         Date et heure de comptage Coordonnées géographiques   latitude  \
# 1402541 2019-12-31 23:00:00+00:00        48.874716,2.292439  48.874716
# 674837  2019-12-31 23:15:00+00:00        48.874716,2.292439  48.874716
# 344303  2019-12-31 23:30:00+00:00        48.874716,2.292439  48.874716
# 1252771 2019-12-31 23:45:00+00:00        48.874716,2.292439  48.874716
# 20673   2020-01-01 00:00:00+00:00        48.874716,2.292439  48.874716
#
#         longitude
# 1402541  2.292439
# 674837   2.292439
# 344303   2.292439
# 1252771  2.292439
# 20673    2.292439

# %%
df20_sortedbyplace.shape
# Out:
# (2314738, 6)

# %%
cols = ["Nom du point de comptage", "Coordonnées géographiques", "latitude", "longitude"]
df20_sites = df20[cols].drop_duplicates(subset=["Nom du point de comptage"])
print(df20_sites.shape)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df20_sites
# Out:
# (72, 4)
#                               Nom du point de comptage  \
# 0                    7 avenue de la Grande Armée NO-SE
# 18                         72 boulevard Voltaire NO-SE
# 762                      89 boulevard de Magenta NO-SE
# 4454                            105 rue La Fayette E-O
# 4468                106 avenue Denfert Rochereau NE-SO
# 4953                       97 avenue Denfert Rochereau
# 6592                       67 boulevard Voltaire SE-NO
# 6598                10 avenue de la Grande Armée SE-NO
# 7887              16 avenue de la Porte des Ternes E-O
# 10209                         Pont du Garigliano NO-SE
# 10983                   102 boulevard de Magenta SE-NO
# 11738                      18 quai de l'Hôtel de Ville
# 12464                         27 boulevard Diderot E-O
# 14720                            Voie Georges Pompidou
# 16471                      Face au 48 quai de la marne
# 17221                  77 boulevard Richard Lenoir N-S
# 17983                              Pont National SO-NE
# 25234               26 boulevard de Ménilmontant SE-NO
# 25450    Face au 16 avenue de la  Porte des Ternes O-E
# 29783                           129 rue Lecourbe SO-NE
# 31279                          147 avenue d'Italie S-N
# 31891               33 avenue des Champs Elysées NO-SE
# 33295                           132 rue Lecourbe NE-SO
# 34449                 72 boulevard Richard Lenoir  S-N
# 38601               21 boulevard Auguste Blanqui SO-NE
# 40775                             28 boulevard Diderot
# 40886                               100 rue La Fayette
# 41647                         39 quai François Mauriac
# 54803                       135 avenue Daumesnil SE-NO
# 55322                           Totem 64 Rue de Rivoli
# 55658                       87 avenue de Flandre NE-SO
# 60110                       72 avenue de Flandre SO-NE
# 73450                     Face 104 rue d'Aubervilliers
# 74530                         Face au 70 quai de Bercy
# 75109                                              NaN
# 85685                          Pont de la Concorde N-S
# 89840                               6 rue Julia Bartet
# 91652             2 avenue de la Porte de Bagnolet O-E
# 92120               44 avenue des Champs Elysées SE-NO
# 132798                   152 boulevard du Montparnasse
# 134362              10 boulevard Auguste Blanqui NE-SO
# 135350                       Face au 25 quai de l'Oise
# 135508                              Pont du Garigliano
# 137031               243 boulevard Saint Germain NO-SE
# 170103                            Pont National  NE-SO
# 172461              35 boulevard de Ménilmontant NO-SE
# 200160                         Pont de la Concorde S-N
# 203816                          Pont des Invalides N-S
# 224480              3 avenue de la Porte D'Orléans S-N
# 233039                          Pont des Invalides S-N
# 250863                         180 avenue d'Italie N-S
# 487992                Totem 73 boulevard de Sébastopol
# 489469                   21 boulevard Saint Michel S-N
# 494766                      Totem 85 quai d'Austerlitz
# 494779                            Totem Cours la Reine
# 539569       Face au 8 avenue de la porte de Charenton
# 622396        Face au 4 avenue de la porte de Bagnolet
# 624945                          Pont Charles De Gaulle
# 634621                                  38 rue Turbigo
# 638593                             36 quai de Grenelle
# 641837                                    Quai d'Orsay
# 642477                                   Pont de Bercy
# 681609                          Face au 40 quai D'Issy
# 800007                         27 quai de la Tournelle
# 851386                           72 rue de la Chapelle
# 866918                         74 Boulevard Ornano S-N
# 872886                         69 Boulevard Ornano N-S
# 874926                                90 Rue De Sèvres
# 882020                        30 rue Saint Jacques N-S
# 906774                             20 Avenue de Clichy
# 1042258                   35 boulevard de Ménilmontant
# 1044146                           254 rue de Vaugirard
#
#         Coordonnées géographiques   latitude longitude
# 0                48.87451,2.29215   48.87451   2.29215
# 18               48.86155,2.37407   48.86155   2.37407
# 762            48.877686,2.354471  48.877686  2.354471
# 4454           48.877667,2.350556  48.877667  2.350556
# 4468             48.83521,2.33307   48.83521   2.33307
# 4953             48.83511,2.33338   48.83511   2.33338
# 6592             48.86149,2.37376   48.86149   2.37376
# 6598           48.874716,2.292439  48.874716  2.292439
# 7887            48.88181,2.281546   48.88181  2.281546
# 10209            48.84015,2.26733   48.84015   2.26733
# 10983          48.877726,2.354926  48.877726  2.354926
# 11738            48.85372,2.35702   48.85372   2.35702
# 12464          48.846099,2.375456  48.846099  2.375456
# 14720             48.8484,2.27586    48.8484   2.27586
# 16471           48.891215,2.38573  48.891215   2.38573
# 17221          48.860852,2.372279  48.860852  2.372279
# 17983            48.82658,2.38409   48.82658   2.38409
# 25234            48.86057,2.38886   48.86057   2.38886
# 25450          48.881626,2.281203  48.881626  2.281203
# 29783             48.842091,2.301  48.842091     2.301
# 31279             48.82026,2.3592   48.82026    2.3592
# 31891          48.869831,2.307076  48.869831  2.307076
# 33295            48.84216,2.30115   48.84216   2.30115
# 34449            48.86077,2.37305   48.86077   2.37305
# 38601          48.830449,2.353199  48.830449  2.353199
# 40775          48.846028,2.375429  48.846028  2.375429
# 40886            48.87746,2.35008   48.87746   2.35008
# 41647              48.83436,2.377   48.83436     2.377
# 54803          48.843435,2.383378  48.843435  2.383378
# 55322            48.85735,2.35211   48.85735   2.35211
# 55658            48.88926,2.37472   48.88926   2.37472
# 60110          48.889046,2.374872  48.889046  2.374872
# 73450          48.890457,2.368852  48.890457  2.368852
# 74530           48.829523,2.38699  48.829523   2.38699
# 75109                         NaN        NaN       NaN
# 85685            48.86392,2.31988   48.86392   2.31988
# 89840            48.82636,2.30303   48.82636   2.30303
# 91652            48.86451,2.40932   48.86451   2.40932
# 92120          48.869873,2.307419  48.869873  2.307419
# 132798         48.840801,2.333233  48.840801  2.333233
# 134362           48.83068,2.35348   48.83068   2.35348
# 135350         48.891415,2.384954  48.891415  2.384954
# 135508           48.83992,2.26694   48.83992   2.26694
# 137031           48.86179,2.32014   48.86179   2.32014
# 170103           48.82682,2.38465   48.82682   2.38465
# 172461         48.860528,2.388364  48.860528  2.388364
# 200160           48.86378,2.32003   48.86378   2.32003
# 203816          48.86284,2.310345   48.86284  2.310345
# 224480           48.82108,2.32537   48.82108   2.32537
# 233039           48.86282,2.31061   48.86282   2.31061
# 250863           48.82024,2.35902   48.82024   2.35902
# 487992           48.86377,2.35096   48.86377   2.35096
# 489469         48.851525,2.343298  48.851525  2.343298
# 494766           48.84201,2.36729   48.84201   2.36729
# 494779           48.86462,2.31444   48.86462   2.31444
# 539569         48.830331,2.400551  48.830331  2.400551
# 622396           48.86461,2.40969   48.86461   2.40969
# 624945           48.84223,2.36811   48.84223   2.36811
# 634621           48.86521,2.35358   48.86521   2.35358
# 638593           48.85209,2.28508   48.85209   2.28508
# 641837           48.86288,2.31179   48.86288   2.31179
# 642477           48.83848,2.37587   48.83848   2.37587
# 681609           48.83421,2.26542   48.83421   2.26542
# 800007           48.85013,2.35423   48.85013   2.35423
# 851386           48.89594,2.35953   48.89594   2.35953
# 866918         48.896825,2.345648  48.896825  2.345648
# 872886           48.89696,2.34538   48.89696   2.34538
# 874926           48.84638,2.31529   48.84638   2.31529
# 882020         48.851131,2.345678  48.851131  2.345678
# 906774           48.88529,2.32666   48.88529   2.32666
# 1042258        48.860528,2.388364  48.860528  2.388364
# 1044146          48.83977,2.30198   48.83977   2.30198

# %%
import geopandas as gpd

# 1. Copie du DataFrame de base
df = df20_sites.copy()

# 2. Nettoyage des coordonnées
df['latitude']  = pd.to_numeric(df['latitude'],  errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

df = df.dropna(subset=['latitude', 'longitude'])

# 3. Création d’un GeoDataFrame à partir du DataFrame nettoyé
gdf_sites = gpd.GeoDataFrame(
    df,
    geometry = gpd.points_from_xy(df.longitude, df.latitude),
    crs="EPSG:4326"
)

# 4. Chargement et projection des arrondissements
url_geojson = "https://opendata.paris.fr/explore/dataset/arrondissements/download/?format=geojson&timezone=Europe/Berlin&lang=fr"
gdf_arr = gpd.read_file(url_geojson)
gdf_arr = gdf_arr.to_crs(epsg=4326)

# 5. Spatial join — points dans les polygones
gdf_joined = gpd.sjoin(gdf_sites, gdf_arr, how="left", predicate="within")

# 6. Sélection & renommage des colonnes d’intérêt
df20_final = gdf_joined[
    ["Nom du point de comptage", "Coordonnées géographiques", "latitude", "longitude", "l_ar"]
].rename(columns={"l_ar": "arrondissement"})

df20_final
# Out:
#                               Nom du point de comptage  \
# 0                    7 avenue de la Grande Armée NO-SE
# 18                         72 boulevard Voltaire NO-SE
# 762                      89 boulevard de Magenta NO-SE
# 4454                            105 rue La Fayette E-O
# 4468                106 avenue Denfert Rochereau NE-SO
# 4953                       97 avenue Denfert Rochereau
# 6592                       67 boulevard Voltaire SE-NO
# 6598                10 avenue de la Grande Armée SE-NO
# 7887              16 avenue de la Porte des Ternes E-O
# 10209                         Pont du Garigliano NO-SE
# 10983                   102 boulevard de Magenta SE-NO
# 11738                      18 quai de l'Hôtel de Ville
# 12464                         27 boulevard Diderot E-O
# 14720                            Voie Georges Pompidou
# 16471                      Face au 48 quai de la marne
# 17221                  77 boulevard Richard Lenoir N-S
# 17983                              Pont National SO-NE
# 25234               26 boulevard de Ménilmontant SE-NO
# 25450    Face au 16 avenue de la  Porte des Ternes O-E
# 29783                           129 rue Lecourbe SO-NE
# 31279                          147 avenue d'Italie S-N
# 31891               33 avenue des Champs Elysées NO-SE
# 33295                           132 rue Lecourbe NE-SO
# 34449                 72 boulevard Richard Lenoir  S-N
# 38601               21 boulevard Auguste Blanqui SO-NE
# 40775                             28 boulevard Diderot
# 40886                               100 rue La Fayette
# 41647                         39 quai François Mauriac
# 54803                       135 avenue Daumesnil SE-NO
# 55322                           Totem 64 Rue de Rivoli
# 55658                       87 avenue de Flandre NE-SO
# 60110                       72 avenue de Flandre SO-NE
# 73450                     Face 104 rue d'Aubervilliers
# 74530                         Face au 70 quai de Bercy
# 85685                          Pont de la Concorde N-S
# 89840                               6 rue Julia Bartet
# 91652             2 avenue de la Porte de Bagnolet O-E
# 92120               44 avenue des Champs Elysées SE-NO
# 132798                   152 boulevard du Montparnasse
# 134362              10 boulevard Auguste Blanqui NE-SO
# 135350                       Face au 25 quai de l'Oise
# 135508                              Pont du Garigliano
# 137031               243 boulevard Saint Germain NO-SE
# 170103                            Pont National  NE-SO
# 172461              35 boulevard de Ménilmontant NO-SE
# 200160                         Pont de la Concorde S-N
# 203816                          Pont des Invalides N-S
# 224480              3 avenue de la Porte D'Orléans S-N
# 233039                          Pont des Invalides S-N
# 250863                         180 avenue d'Italie N-S
# 487992                Totem 73 boulevard de Sébastopol
# 489469                   21 boulevard Saint Michel S-N
# 494766                      Totem 85 quai d'Austerlitz
# 494779                            Totem Cours la Reine
# 539569       Face au 8 avenue de la porte de Charenton
# 622396        Face au 4 avenue de la porte de Bagnolet
# 624945                          Pont Charles De Gaulle
# 634621                                  38 rue Turbigo
# 638593                             36 quai de Grenelle
# 641837                                    Quai d'Orsay
# 642477                                   Pont de Bercy
# 681609                          Face au 40 quai D'Issy
# 800007                         27 quai de la Tournelle
# 851386                           72 rue de la Chapelle
# 866918                         74 Boulevard Ornano S-N
# 872886                         69 Boulevard Ornano N-S
# 874926                                90 Rue De Sèvres
# 882020                        30 rue Saint Jacques N-S
# 906774                             20 Avenue de Clichy
# 1042258                   35 boulevard de Ménilmontant
# 1044146                           254 rue de Vaugirard
#
#         Coordonnées géographiques   latitude  longitude arrondissement
# 0                48.87451,2.29215  48.874510   2.292150     16ème Ardt
# 18               48.86155,2.37407  48.861550   2.374070     11ème Ardt
# 762            48.877686,2.354471  48.877686   2.354471     10ème Ardt
# 4454           48.877667,2.350556  48.877667   2.350556     10ème Ardt
# 4468             48.83521,2.33307  48.835210   2.333070     14ème Ardt
# 4953             48.83511,2.33338  48.835110   2.333380     14ème Ardt
# 6592             48.86149,2.37376  48.861490   2.373760     11ème Ardt
# 6598           48.874716,2.292439  48.874716   2.292439     17ème Ardt
# 7887            48.88181,2.281546  48.881810   2.281546     17ème Ardt
# 10209            48.84015,2.26733  48.840150   2.267330     16ème Ardt
# 10983          48.877726,2.354926  48.877726   2.354926     10ème Ardt
# 11738            48.85372,2.35702  48.853720   2.357020      4ème Ardt
# 12464          48.846099,2.375456  48.846099   2.375456     12ème Ardt
# 14720             48.8484,2.27586  48.848400   2.275860     16ème Ardt
# 16471           48.891215,2.38573  48.891215   2.385730     19ème Ardt
# 17221          48.860852,2.372279  48.860852   2.372279     11ème Ardt
# 17983            48.82658,2.38409  48.826580   2.384090     13ème Ardt
# 25234            48.86057,2.38886  48.860570   2.388860     20ème Ardt
# 25450          48.881626,2.281203  48.881626   2.281203     17ème Ardt
# 29783             48.842091,2.301  48.842091   2.301000     15ème Ardt
# 31279             48.82026,2.3592  48.820260   2.359200     13ème Ardt
# 31891          48.869831,2.307076  48.869831   2.307076      8ème Ardt
# 33295            48.84216,2.30115  48.842160   2.301150     15ème Ardt
# 34449            48.86077,2.37305  48.860770   2.373050     11ème Ardt
# 38601          48.830449,2.353199  48.830449   2.353199     13ème Ardt
# 40775          48.846028,2.375429  48.846028   2.375429     12ème Ardt
# 40886            48.87746,2.35008  48.877460   2.350080     10ème Ardt
# 41647              48.83436,2.377  48.834360   2.377000     13ème Ardt
# 54803          48.843435,2.383378  48.843435   2.383378     12ème Ardt
# 55322            48.85735,2.35211  48.857350   2.352110      4ème Ardt
# 55658            48.88926,2.37472  48.889260   2.374720     19ème Ardt
# 60110          48.889046,2.374872  48.889046   2.374872     19ème Ardt
# 73450          48.890457,2.368852  48.890457   2.368852     19ème Ardt
# 74530           48.829523,2.38699  48.829523   2.386990     12ème Ardt
# 85685            48.86392,2.31988  48.863920   2.319880      8ème Ardt
# 89840            48.82636,2.30303  48.826360   2.303030     14ème Ardt
# 91652            48.86451,2.40932  48.864510   2.409320     20ème Ardt
# 92120          48.869873,2.307419  48.869873   2.307419      8ème Ardt
# 132798         48.840801,2.333233  48.840801   2.333233      6ème Ardt
# 134362           48.83068,2.35348  48.830680   2.353480     13ème Ardt
# 135350         48.891415,2.384954  48.891415   2.384954     19ème Ardt
# 135508           48.83992,2.26694  48.839920   2.266940     16ème Ardt
# 137031           48.86179,2.32014  48.861790   2.320140      7ème Ardt
# 170103           48.82682,2.38465  48.826820   2.384650     13ème Ardt
# 172461         48.860528,2.388364  48.860528   2.388364     11ème Ardt
# 200160           48.86378,2.32003  48.863780   2.320030      8ème Ardt
# 203816          48.86284,2.310345  48.862840   2.310345      7ème Ardt
# 224480           48.82108,2.32537  48.821080   2.325370     14ème Ardt
# 233039           48.86282,2.31061  48.862820   2.310610      7ème Ardt
# 250863           48.82024,2.35902  48.820240   2.359020     13ème Ardt
# 487992           48.86377,2.35096  48.863770   2.350960      2ème Ardt
# 489469         48.851525,2.343298  48.851525   2.343298      5ème Ardt
# 494766           48.84201,2.36729  48.842010   2.367290     13ème Ardt
# 494779           48.86462,2.31444  48.864620   2.314440      8ème Ardt
# 539569         48.830331,2.400551  48.830331   2.400551     12ème Ardt
# 622396           48.86461,2.40969  48.864610   2.409690     20ème Ardt
# 624945           48.84223,2.36811  48.842230   2.368110     13ème Ardt
# 634621           48.86521,2.35358  48.865210   2.353580      3ème Ardt
# 638593           48.85209,2.28508  48.852090   2.285080     15ème Ardt
# 641837           48.86288,2.31179  48.862880   2.311790      7ème Ardt
# 642477           48.83848,2.37587  48.838480   2.375870     12ème Ardt
# 681609           48.83421,2.26542  48.834210   2.265420            NaN
# 800007           48.85013,2.35423  48.850130   2.354230      5ème Ardt
# 851386           48.89594,2.35953  48.895940   2.359530     18ème Ardt
# 866918         48.896825,2.345648  48.896825   2.345648     18ème Ardt
# 872886           48.89696,2.34538  48.896960   2.345380     18ème Ardt
# 874926           48.84638,2.31529  48.846380   2.315290     15ème Ardt
# 882020         48.851131,2.345678  48.851131   2.345678      5ème Ardt
# 906774           48.88529,2.32666  48.885290   2.326660     18ème Ardt
# 1042258        48.860528,2.388364  48.860528   2.388364     11ème Ardt
# 1044146          48.83977,2.30198  48.839770   2.301980     15ème Ardt

# %%
import pandas as pd

def list_to_semicolon_str(lst):
    return "; ".join(str(v) for v in lst if pd.notna(v))

# Regroupement par arrondissement et concaténation des coordonnées
tableau_arr = (
    df20_final
    .groupby("arrondissement", dropna=False)
    .agg({
        "Coordonnées géographiques": lambda x: list_to_semicolon_str(x),
        "latitude": lambda x: list_to_semicolon_str(x),
        "longitude": lambda x: list_to_semicolon_str(x)
    })
    .reset_index()
)

# Trier les arrondissements par numéro — si le nom contient un nombre
# On extrait le premier nombre trouvé dans la chaîne (ex “12e”, “8”, etc.)
tableau_arr['arr_num'] = (
    tableau_arr['arrondissement']
    .str.extract(r'(\d+)', expand=False)  # capture les chiffres
    .astype(float, errors='ignore')       # convertit en float si possible
)

# Trier par ce numéro, en mettant les NaN (arrondissements sans numéro numérique) à la fin
tableau_arr = tableau_arr.sort_values(
    by='arr_num', na_position='last'
).drop(columns='arr_num').reset_index(drop=True)

# Optionnel : afficher tout, mais attention si le tableau est très long
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

tableau_arr
# Out:
#    arrondissement  \
# 0       2ème Ardt
# 1       3ème Ardt
# 2       4ème Ardt
# 3       5ème Ardt
# 4       6ème Ardt
# 5       7ème Ardt
# 6       8ème Ardt
# 7      10ème Ardt
# 8      11ème Ardt
# 9      12ème Ardt
# 10     13ème Ardt
# 11     14ème Ardt
# 12     15ème Ardt
# 13     16ème Ardt
# 14     17ème Ardt
# 15     18ème Ardt
# 16     19ème Ardt
# 17     20ème Ardt
# 18            NaN
#
#                                                                                                                                           Coordonnées géographiques  \
# 0                                                                                                                                                  48.86377,2.35096
# 1                                                                                                                                                  48.86521,2.35358
# 2                                                                                                                                48.85372,2.35702; 48.85735,2.35211
# 3                                                                                                          48.851525,2.343298; 48.85013,2.35423; 48.851131,2.345678
# 4                                                                                                                                                48.840801,2.333233
# 5                                                                                           48.86179,2.32014; 48.86284,2.310345; 48.86282,2.31061; 48.86288,2.31179
# 6                                                                      48.869831,2.307076; 48.86392,2.31988; 48.869873,2.307419; 48.86378,2.32003; 48.86462,2.31444
# 7                                                                                      48.877686,2.354471; 48.877667,2.350556; 48.877726,2.354926; 48.87746,2.35008
# 8                                                  48.86155,2.37407; 48.86149,2.37376; 48.860852,2.372279; 48.86077,2.37305; 48.860528,2.388364; 48.860528,2.388364
# 9                                               48.846099,2.375456; 48.846028,2.375429; 48.843435,2.383378; 48.829523,2.38699; 48.830331,2.400551; 48.83848,2.37587
# 10  48.82658,2.38409; 48.82026,2.3592; 48.830449,2.353199; 48.83436,2.377; 48.83068,2.35348; 48.82682,2.38465; 48.82024,2.35902; 48.84201,2.36729; 48.84223,2.36811
# 11                                                                                           48.83521,2.33307; 48.83511,2.33338; 48.82636,2.30303; 48.82108,2.32537
# 12                                                                          48.842091,2.301; 48.84216,2.30115; 48.85209,2.28508; 48.84638,2.31529; 48.83977,2.30198
# 13                                                                                            48.87451,2.29215; 48.84015,2.26733; 48.8484,2.27586; 48.83992,2.26694
# 14                                                                                                        48.874716,2.292439; 48.88181,2.281546; 48.881626,2.281203
# 15                                                                                         48.89594,2.35953; 48.896825,2.345648; 48.89696,2.34538; 48.88529,2.32666
# 16                                                                  48.891215,2.38573; 48.88926,2.37472; 48.889046,2.374872; 48.890457,2.368852; 48.891415,2.384954
# 17                                                                                                             48.86057,2.38886; 48.86451,2.40932; 48.86461,2.40969
# 18                                                                                                                                                 48.83421,2.26542
#
#                                                                                      latitude  \
# 0                                                                                    48.86377
# 1                                                                                    48.86521
# 2                                                                          48.85372; 48.85735
# 3                                                              48.851525; 48.85013; 48.851131
# 4                                                                                   48.840801
# 5                                                      48.86179; 48.86284; 48.86282; 48.86288
# 6                                          48.869831; 48.86392; 48.869873; 48.86378; 48.86462
# 7                                                   48.877686; 48.877667; 48.877726; 48.87746
# 8                               48.86155; 48.86149; 48.860852; 48.86077; 48.860528; 48.860528
# 9                             48.846099; 48.846028; 48.843435; 48.829523; 48.830331; 48.83848
# 10  48.82658; 48.82026; 48.830449; 48.83436; 48.83068; 48.82682; 48.82024; 48.84201; 48.84223
# 11                                                     48.83521; 48.83511; 48.82636; 48.82108
# 12                                          48.842091; 48.84216; 48.85209; 48.84638; 48.83977
# 13                                                      48.87451; 48.84015; 48.8484; 48.83992
# 14                                                             48.874716; 48.88181; 48.881626
# 15                                                    48.89594; 48.896825; 48.89696; 48.88529
# 16                                       48.891215; 48.88926; 48.889046; 48.890457; 48.891415
# 17                                                               48.86057; 48.86451; 48.86461
# 18                                                                                   48.83421
#
#                                                                         longitude
# 0                                                                         2.35096
# 1                                                                         2.35358
# 2                                                                2.35702; 2.35211
# 3                                                     2.343298; 2.35423; 2.345678
# 4                                                                        2.333233
# 5                                             2.32014; 2.310345; 2.31061; 2.31179
# 6                                   2.307076; 2.31988; 2.307419; 2.32003; 2.31444
# 7                                           2.354471; 2.350556; 2.354926; 2.35008
# 8                         2.37407; 2.37376; 2.372279; 2.37305; 2.388364; 2.388364
# 9                        2.375456; 2.375429; 2.383378; 2.38699; 2.400551; 2.37587
# 10  2.38409; 2.3592; 2.353199; 2.377; 2.35348; 2.38465; 2.35902; 2.36729; 2.36811
# 11                                             2.33307; 2.33338; 2.30303; 2.32537
# 12                                      2.301; 2.30115; 2.28508; 2.31529; 2.30198
# 13                                             2.29215; 2.26733; 2.27586; 2.26694
# 14                                                   2.292439; 2.281546; 2.281203
# 15                                            2.35953; 2.345648; 2.34538; 2.32666
# 16                                 2.38573; 2.37472; 2.374872; 2.368852; 2.384954
# 17                                                      2.38886; 2.40932; 2.40969
# 18                                                                        2.26542

# %%
df20.shape
# Out:
# (2314738, 6)

# %%
df20["Date et heure de comptage"] = pd.to_datetime(df20["Date et heure de comptage"], utc=True)
df20["Date et heure de comptage"] = df20["Date et heure de comptage"].dt.tz_convert("Europe/Paris")
date_min = df20["Date et heure de comptage"].min()
date_max = df20["Date et heure de comptage"].max()

print("Date la plus ancienne :", date_min)
print("Date la plus récente :", date_max)
# Out:
# Date la plus ancienne : 2020-01-01 00:00:00+01:00
# Date la plus récente : 2020-12-31 23:45:00+01:00

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
ANNEE = 2020
START_DATE = "2020-01-01"
END_DATE   = "2020-12-31"

results_temp = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df20_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"📡 Récupération météo pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=apparent_temperature"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        temps  = data["hourly"].get("apparent_temperature", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, temp in zip(heures, temps):
            results_temp.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "temperature_apparente": temp
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df20_temp_horaire = pd.DataFrame(results_temp)

# Conversion datetime
df20_temp_horaire["datetime"] = pd.to_datetime(
    df20_temp_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df20_temp_horaire = df20_temp_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2020_temperature_horaire_par_site_comptage.csv"
)

df20_temp_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df20_temp_horaire.head(20))
# Out:
# 📡 Récupération météo pour : 7 avenue de la Grande Armée NO-SE
# 📡 Récupération météo pour : 72 boulevard Voltaire NO-SE
# 📡 Récupération météo pour : 89 boulevard de Magenta NO-SE
# 📡 Récupération météo pour : 105 rue La Fayette E-O
# 📡 Récupération météo pour : 106 avenue Denfert Rochereau NE-SO
# 📡 Récupération météo pour : 97 avenue Denfert Rochereau
# 📡 Récupération météo pour : 67 boulevard Voltaire SE-NO
# 📡 Récupération météo pour : 10 avenue de la Grande Armée SE-NO
# 📡 Récupération météo pour : 16 avenue de la Porte des Ternes E-O
# 📡 Récupération météo pour : Pont du Garigliano NO-SE
# 📡 Récupération météo pour : 102 boulevard de Magenta SE-NO
# 📡 Récupération météo pour : 18 quai de l'Hôtel de Ville
# 📡 Récupération météo pour : 27 boulevard Diderot E-O
# 📡 Récupération météo pour : Voie Georges Pompidou
# 📡 Récupération météo pour : Face au 48 quai de la marne
# 📡 Récupération météo pour : 77 boulevard Richard Lenoir N-S
# 📡 Récupération météo pour : Pont National SO-NE
# 📡 Récupération météo pour : 26 boulevard de Ménilmontant SE-NO
# 📡 Récupération météo pour : Face au 16 avenue de la  Porte des Ternes O-E
# 📡 Récupération météo pour : 129 rue Lecourbe SO-NE
# 📡 Récupération météo pour : 147 avenue d'Italie S-N
# 📡 Récupération météo pour : 33 avenue des Champs Elysées NO-SE
# 📡 Récupération météo pour : 132 rue Lecourbe NE-SO
# 📡 Récupération météo pour : 72 boulevard Richard Lenoir  S-N
# 📡 Récupération météo pour : 21 boulevard Auguste Blanqui SO-NE
# 📡 Récupération météo pour : 28 boulevard Diderot
# 📡 Récupération météo pour : 100 rue La Fayette
# 📡 Récupération météo pour : 39 quai François Mauriac
# 📡 Récupération météo pour : 135 avenue Daumesnil SE-NO
# 📡 Récupération météo pour : Totem 64 Rue de Rivoli
# 📡 Récupération météo pour : 87 avenue de Flandre NE-SO
# 📡 Récupération météo pour : 72 avenue de Flandre SO-NE
# 📡 Récupération météo pour : Face 104 rue d'Aubervilliers
# 📡 Récupération météo pour : Face au 70 quai de Bercy
# 📡 Récupération météo pour : Pont de la Concorde N-S
# 📡 Récupération météo pour : 6 rue Julia Bartet
# 📡 Récupération météo pour : 2 avenue de la Porte de Bagnolet O-E
# 📡 Récupération météo pour : 44 avenue des Champs Elysées SE-NO
# 📡 Récupération météo pour : 152 boulevard du Montparnasse
# 📡 Récupération météo pour : 10 boulevard Auguste Blanqui NE-SO
# 📡 Récupération météo pour : Face au 25 quai de l'Oise
# 📡 Récupération météo pour : Pont du Garigliano
# 📡 Récupération météo pour : 243 boulevard Saint Germain NO-SE
# 📡 Récupération météo pour : Pont National  NE-SO
# 📡 Récupération météo pour : 35 boulevard de Ménilmontant NO-SE
# 📡 Récupération météo pour : Pont de la Concorde S-N
# 📡 Récupération météo pour : Pont des Invalides N-S
# 📡 Récupération météo pour : 3 avenue de la Porte D'Orléans S-N
# 📡 Récupération météo pour : Pont des Invalides S-N
# 📡 Récupération météo pour : 180 avenue d'Italie N-S
# 📡 Récupération météo pour : Totem 73 boulevard de Sébastopol
# 📡 Récupération météo pour : 21 boulevard Saint Michel S-N
# 📡 Récupération météo pour : Totem 85 quai d'Austerlitz
# 📡 Récupération météo pour : Totem Cours la Reine
# 📡 Récupération météo pour : Face au 8 avenue de la porte de Charenton
# 📡 Récupération météo pour : Face au 4 avenue de la porte de Bagnolet
# 📡 Récupération météo pour : Pont Charles De Gaulle
# 📡 Récupération météo pour : 38 rue Turbigo
# 📡 Récupération météo pour : 36 quai de Grenelle
# 📡 Récupération météo pour : Quai d'Orsay
# 📡 Récupération météo pour : Pont de Bercy
# 📡 Récupération météo pour : Face au 40 quai D'Issy
# 📡 Récupération météo pour : 27 quai de la Tournelle
# 📡 Récupération météo pour : 72 rue de la Chapelle
# 📡 Récupération météo pour : 74 Boulevard Ornano S-N
# 📡 Récupération météo pour : 69 Boulevard Ornano N-S
# 📡 Récupération météo pour : 90 Rue De Sèvres
# 📡 Récupération météo pour : 30 rue Saint Jacques N-S
# 📡 Récupération météo pour : 20 Avenue de Clichy
# 📡 Récupération météo pour : 35 boulevard de Ménilmontant
# 📡 Récupération météo pour : 254 rue de Vaugirard
# ✅ Données sauvegardées dans data/2020_temperature_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  temperature_apparente
# 0  2020-01-01 00:00:00                   -3.9
# 1  2020-01-01 01:00:00                   -0.1
# 2  2020-01-01 02:00:00                   -0.9
# 3  2020-01-01 03:00:00                   -1.3
# 4  2020-01-01 04:00:00                   -1.2
# 5  2020-01-01 05:00:00                   -1.3
# 6  2020-01-01 06:00:00                   -0.8
# 7  2020-01-01 07:00:00                   -1.0
# 8  2020-01-01 08:00:00                   -1.3
# 9  2020-01-01 09:00:00                   -1.4
# 10 2020-01-01 10:00:00                   -1.1
# 11 2020-01-01 11:00:00                   -0.9
# 12 2020-01-01 12:00:00                   -0.4
# 13 2020-01-01 13:00:00                    0.2
# 14 2020-01-01 14:00:00                    0.5
# 15 2020-01-01 15:00:00                    0.8
# 16 2020-01-01 16:00:00                    0.8
# 17 2020-01-01 17:00:00                    1.0
# 18 2020-01-01 18:00:00                    1.0
# 19 2020-01-01 19:00:00                    1.0

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
ANNEE = 2020
START_DATE = "2020-01-01"
END_DATE   = "2020-12-31"

results_precip = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df20_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"🌧️ Récupération précipitations pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=precipitation"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        prec   = data["hourly"].get("precipitation", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, p in zip(heures, prec):
            results_precip.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "precipitation_mm": p
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df20_precip_horaire = pd.DataFrame(results_precip)

# Conversion datetime
df20_precip_horaire["datetime"] = pd.to_datetime(
    df20_precip_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df20_precip_horaire = df20_precip_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2020_precipitation_horaire_par_site_comptage.csv"
)

df20_precip_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df20_precip_horaire.head(20))
# Out:
# 🌧️ Récupération précipitations pour : 7 avenue de la Grande Armée NO-SE
# 🌧️ Récupération précipitations pour : 72 boulevard Voltaire NO-SE
# 🌧️ Récupération précipitations pour : 89 boulevard de Magenta NO-SE
# 🌧️ Récupération précipitations pour : 105 rue La Fayette E-O
# 🌧️ Récupération précipitations pour : 106 avenue Denfert Rochereau NE-SO
# 🌧️ Récupération précipitations pour : 97 avenue Denfert Rochereau
# 🌧️ Récupération précipitations pour : 67 boulevard Voltaire SE-NO
# 🌧️ Récupération précipitations pour : 10 avenue de la Grande Armée SE-NO
# 🌧️ Récupération précipitations pour : 16 avenue de la Porte des Ternes E-O
# 🌧️ Récupération précipitations pour : Pont du Garigliano NO-SE
# 🌧️ Récupération précipitations pour : 102 boulevard de Magenta SE-NO
# 🌧️ Récupération précipitations pour : 18 quai de l'Hôtel de Ville
# 🌧️ Récupération précipitations pour : 27 boulevard Diderot E-O
# 🌧️ Récupération précipitations pour : Voie Georges Pompidou
# 🌧️ Récupération précipitations pour : Face au 48 quai de la marne
# 🌧️ Récupération précipitations pour : 77 boulevard Richard Lenoir N-S
# 🌧️ Récupération précipitations pour : Pont National SO-NE
# 🌧️ Récupération précipitations pour : 26 boulevard de Ménilmontant SE-NO
# 🌧️ Récupération précipitations pour : Face au 16 avenue de la  Porte des Ternes O-E
# 🌧️ Récupération précipitations pour : 129 rue Lecourbe SO-NE
# 🌧️ Récupération précipitations pour : 147 avenue d'Italie S-N
# 🌧️ Récupération précipitations pour : 33 avenue des Champs Elysées NO-SE
# 🌧️ Récupération précipitations pour : 132 rue Lecourbe NE-SO
# 🌧️ Récupération précipitations pour : 72 boulevard Richard Lenoir  S-N
# 🌧️ Récupération précipitations pour : 21 boulevard Auguste Blanqui SO-NE
# 🌧️ Récupération précipitations pour : 28 boulevard Diderot
# 🌧️ Récupération précipitations pour : 100 rue La Fayette
# 🌧️ Récupération précipitations pour : 39 quai François Mauriac
# 🌧️ Récupération précipitations pour : 135 avenue Daumesnil SE-NO
# 🌧️ Récupération précipitations pour : Totem 64 Rue de Rivoli
# 🌧️ Récupération précipitations pour : 87 avenue de Flandre NE-SO
# 🌧️ Récupération précipitations pour : 72 avenue de Flandre SO-NE
# 🌧️ Récupération précipitations pour : Face 104 rue d'Aubervilliers
# 🌧️ Récupération précipitations pour : Face au 70 quai de Bercy
# 🌧️ Récupération précipitations pour : Pont de la Concorde N-S
# 🌧️ Récupération précipitations pour : 6 rue Julia Bartet
# 🌧️ Récupération précipitations pour : 2 avenue de la Porte de Bagnolet O-E
# 🌧️ Récupération précipitations pour : 44 avenue des Champs Elysées SE-NO
# 🌧️ Récupération précipitations pour : 152 boulevard du Montparnasse
# 🌧️ Récupération précipitations pour : 10 boulevard Auguste Blanqui NE-SO
# 🌧️ Récupération précipitations pour : Face au 25 quai de l'Oise
# 🌧️ Récupération précipitations pour : Pont du Garigliano
# 🌧️ Récupération précipitations pour : 243 boulevard Saint Germain NO-SE
# 🌧️ Récupération précipitations pour : Pont National  NE-SO
# 🌧️ Récupération précipitations pour : 35 boulevard de Ménilmontant NO-SE
# 🌧️ Récupération précipitations pour : Pont de la Concorde S-N
# 🌧️ Récupération précipitations pour : Pont des Invalides N-S
# 🌧️ Récupération précipitations pour : 3 avenue de la Porte D'Orléans S-N
# 🌧️ Récupération précipitations pour : Pont des Invalides S-N
# 🌧️ Récupération précipitations pour : 180 avenue d'Italie N-S
# 🌧️ Récupération précipitations pour : Totem 73 boulevard de Sébastopol
# 🌧️ Récupération précipitations pour : 21 boulevard Saint Michel S-N
# 🌧️ Récupération précipitations pour : Totem 85 quai d'Austerlitz
# 🌧️ Récupération précipitations pour : Totem Cours la Reine
# 🌧️ Récupération précipitations pour : Face au 8 avenue de la porte de Charenton
# 🌧️ Récupération précipitations pour : Face au 4 avenue de la porte de Bagnolet
# 🌧️ Récupération précipitations pour : Pont Charles De Gaulle
# 🌧️ Récupération précipitations pour : 38 rue Turbigo
# 🌧️ Récupération précipitations pour : 36 quai de Grenelle
# 🌧️ Récupération précipitations pour : Quai d'Orsay
# 🌧️ Récupération précipitations pour : Pont de Bercy
# 🌧️ Récupération précipitations pour : Face au 40 quai D'Issy
# 🌧️ Récupération précipitations pour : 27 quai de la Tournelle
# 🌧️ Récupération précipitations pour : 72 rue de la Chapelle
# 🌧️ Récupération précipitations pour : 74 Boulevard Ornano S-N
# 🌧️ Récupération précipitations pour : 69 Boulevard Ornano N-S
# 🌧️ Récupération précipitations pour : 90 Rue De Sèvres
# 🌧️ Récupération précipitations pour : 30 rue Saint Jacques N-S
# 🌧️ Récupération précipitations pour : 20 Avenue de Clichy
# 🌧️ Récupération précipitations pour : 35 boulevard de Ménilmontant
# 🌧️ Récupération précipitations pour : 254 rue de Vaugirard
# ✅ Données sauvegardées dans data/2020_precipitation_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  precipitation_mm
# 0  2020-01-01 00:00:00               0.0
# 1  2020-01-01 01:00:00               0.0
# 2  2020-01-01 02:00:00               0.0
# 3  2020-01-01 03:00:00               0.0
# 4  2020-01-01 04:00:00               0.0
# 5  2020-01-01 05:00:00               0.0
# 6  2020-01-01 06:00:00               0.0
# 7  2020-01-01 07:00:00               0.0
# 8  2020-01-01 08:00:00               0.0
# 9  2020-01-01 09:00:00               0.0
# 10 2020-01-01 10:00:00               0.0
# 11 2020-01-01 11:00:00               0.0
# 12 2020-01-01 12:00:00               0.0
# 13 2020-01-01 13:00:00               0.0
# 14 2020-01-01 14:00:00               0.0
# 15 2020-01-01 15:00:00               0.0
# 16 2020-01-01 16:00:00               0.0
# 17 2020-01-01 17:00:00               0.0
# 18 2020-01-01 18:00:00               0.1
# 19 2020-01-01 19:00:00               0.1

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
START_DATE = "2020-01-01"
END_DATE   = "2020-12-31"

results_cloud = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df20_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"☁️ Récupération cloud_cover pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=cloud_cover"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        clouds = data["hourly"].get("cloud_cover", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, c in zip(heures, clouds):
            results_cloud.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "cloud_cover_pct": c
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df20_cloud_horaire = pd.DataFrame(results_cloud)

# Conversion datetime
df20_cloud_horaire["datetime"] = pd.to_datetime(
    df20_cloud_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df20_cloud_horaire = df20_cloud_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2020_cloud_cover_horaire_par_site_comptage.csv"
)

df20_cloud_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df20_cloud_horaire.head(20))
# Out:
# ☁️ Récupération cloud_cover pour : 7 avenue de la Grande Armée NO-SE
# ☁️ Récupération cloud_cover pour : 72 boulevard Voltaire NO-SE
# ☁️ Récupération cloud_cover pour : 89 boulevard de Magenta NO-SE
# ☁️ Récupération cloud_cover pour : 105 rue La Fayette E-O
# ☁️ Récupération cloud_cover pour : 106 avenue Denfert Rochereau NE-SO
# ☁️ Récupération cloud_cover pour : 97 avenue Denfert Rochereau
# ☁️ Récupération cloud_cover pour : 67 boulevard Voltaire SE-NO
# ☁️ Récupération cloud_cover pour : 10 avenue de la Grande Armée SE-NO
# ☁️ Récupération cloud_cover pour : 16 avenue de la Porte des Ternes E-O
# ☁️ Récupération cloud_cover pour : Pont du Garigliano NO-SE
# ☁️ Récupération cloud_cover pour : 102 boulevard de Magenta SE-NO
# ☁️ Récupération cloud_cover pour : 18 quai de l'Hôtel de Ville
# ☁️ Récupération cloud_cover pour : 27 boulevard Diderot E-O
# ☁️ Récupération cloud_cover pour : Voie Georges Pompidou
# ☁️ Récupération cloud_cover pour : Face au 48 quai de la marne
# ☁️ Récupération cloud_cover pour : 77 boulevard Richard Lenoir N-S
# ☁️ Récupération cloud_cover pour : Pont National SO-NE
# ☁️ Récupération cloud_cover pour : 26 boulevard de Ménilmontant SE-NO
# ☁️ Récupération cloud_cover pour : Face au 16 avenue de la  Porte des Ternes O-E
# ☁️ Récupération cloud_cover pour : 129 rue Lecourbe SO-NE
# ☁️ Récupération cloud_cover pour : 147 avenue d'Italie S-N
# ☁️ Récupération cloud_cover pour : 33 avenue des Champs Elysées NO-SE
# ☁️ Récupération cloud_cover pour : 132 rue Lecourbe NE-SO
# ☁️ Récupération cloud_cover pour : 72 boulevard Richard Lenoir  S-N
# ☁️ Récupération cloud_cover pour : 21 boulevard Auguste Blanqui SO-NE
# ☁️ Récupération cloud_cover pour : 28 boulevard Diderot
# ☁️ Récupération cloud_cover pour : 100 rue La Fayette
# ☁️ Récupération cloud_cover pour : 39 quai François Mauriac
# ☁️ Récupération cloud_cover pour : 135 avenue Daumesnil SE-NO
# ☁️ Récupération cloud_cover pour : Totem 64 Rue de Rivoli
# ☁️ Récupération cloud_cover pour : 87 avenue de Flandre NE-SO
# ☁️ Récupération cloud_cover pour : 72 avenue de Flandre SO-NE
# ☁️ Récupération cloud_cover pour : Face 104 rue d'Aubervilliers
# ☁️ Récupération cloud_cover pour : Face au 70 quai de Bercy
# ☁️ Récupération cloud_cover pour : Pont de la Concorde N-S
# ☁️ Récupération cloud_cover pour : 6 rue Julia Bartet
# ☁️ Récupération cloud_cover pour : 2 avenue de la Porte de Bagnolet O-E
# ☁️ Récupération cloud_cover pour : 44 avenue des Champs Elysées SE-NO
# ☁️ Récupération cloud_cover pour : 152 boulevard du Montparnasse
# ☁️ Récupération cloud_cover pour : 10 boulevard Auguste Blanqui NE-SO
# ☁️ Récupération cloud_cover pour : Face au 25 quai de l'Oise
# ☁️ Récupération cloud_cover pour : Pont du Garigliano
# ☁️ Récupération cloud_cover pour : 243 boulevard Saint Germain NO-SE
# ☁️ Récupération cloud_cover pour : Pont National  NE-SO
# ☁️ Récupération cloud_cover pour : 35 boulevard de Ménilmontant NO-SE
# ☁️ Récupération cloud_cover pour : Pont de la Concorde S-N
# ☁️ Récupération cloud_cover pour : Pont des Invalides N-S
# ☁️ Récupération cloud_cover pour : 3 avenue de la Porte D'Orléans S-N
# ☁️ Récupération cloud_cover pour : Pont des Invalides S-N
# ☁️ Récupération cloud_cover pour : 180 avenue d'Italie N-S
# ☁️ Récupération cloud_cover pour : Totem 73 boulevard de Sébastopol
# ☁️ Récupération cloud_cover pour : 21 boulevard Saint Michel S-N
# ☁️ Récupération cloud_cover pour : Totem 85 quai d'Austerlitz
# ☁️ Récupération cloud_cover pour : Totem Cours la Reine
# ☁️ Récupération cloud_cover pour : Face au 8 avenue de la porte de Charenton
# ☁️ Récupération cloud_cover pour : Face au 4 avenue de la porte de Bagnolet
# ☁️ Récupération cloud_cover pour : Pont Charles De Gaulle
# ☁️ Récupération cloud_cover pour : 38 rue Turbigo
# ☁️ Récupération cloud_cover pour : 36 quai de Grenelle
# ☁️ Récupération cloud_cover pour : Quai d'Orsay
# ☁️ Récupération cloud_cover pour : Pont de Bercy
# ☁️ Récupération cloud_cover pour : Face au 40 quai D'Issy
# ☁️ Récupération cloud_cover pour : 27 quai de la Tournelle
# ☁️ Récupération cloud_cover pour : 72 rue de la Chapelle
# ☁️ Récupération cloud_cover pour : 74 Boulevard Ornano S-N
# ☁️ Récupération cloud_cover pour : 69 Boulevard Ornano N-S
# ☁️ Récupération cloud_cover pour : 90 Rue De Sèvres
# ☁️ Récupération cloud_cover pour : 30 rue Saint Jacques N-S
# ☁️ Récupération cloud_cover pour : 20 Avenue de Clichy
# ☁️ Récupération cloud_cover pour : 35 boulevard de Ménilmontant
# ☁️ Récupération cloud_cover pour : 254 rue de Vaugirard
# ✅ Données sauvegardées dans data/2020_cloud_cover_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  cloud_cover_pct
# 0  2020-01-01 00:00:00              100
# 1  2020-01-01 01:00:00              100
# 2  2020-01-01 02:00:00               94
# 3  2020-01-01 03:00:00               92
# 4  2020-01-01 04:00:00               93
# 5  2020-01-01 05:00:00               94
# 6  2020-01-01 06:00:00              100
# 7  2020-01-01 07:00:00              100
# 8  2020-01-01 08:00:00              100
# 9  2020-01-01 09:00:00              100
# 10 2020-01-01 10:00:00              100
# 11 2020-01-01 11:00:00              100
# 12 2020-01-01 12:00:00              100
# 13 2020-01-01 13:00:00              100
# 14 2020-01-01 14:00:00              100
# 15 2020-01-01 15:00:00              100
# 16 2020-01-01 16:00:00              100
# 17 2020-01-01 17:00:00              100
# 18 2020-01-01 18:00:00              100
# 19 2020-01-01 19:00:00              100
