# %%
import pandas as pd

# %%
df21 = pd.read_csv("data/2021_comptage-velo-donnees-sites-comptage.csv", on_bad_lines='skip')
df21.head()
# Out:
#                                                     Identifiant du point de comptage;Nom du point de comptage;Comptage horaire;Date et heure de comptage;Lien vers photo du point de comptage;Coordonnées géographiques
# 100003097;105 rue La Fayette E-O;0.0;2021-01-01...                                             2.3506
# 100003097;105 rue La Fayette E-O;1.0;2021-01-01...                                             2.3506
# 100003097;105 rue La Fayette E-O;1.0;2021-01-01...                                             2.3506
# 100003097;105 rue La Fayette E-O;0.0;2021-01-01...                                             2.3506
# 100003097;105 rue La Fayette E-O;2.0;2021-01-01...                                             2.3506

# %%
list(df21.columns)
# Out:
# ['Identifiant du point de comptage;Nom du point de comptage;Comptage horaire;Date et heure de comptage;Lien vers photo du point de comptage;Coordonnées géographiques']

# %%
colsToKeep = [
    # 'Identifiant du point de comptage',
    'Nom du point de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #'Lien vers photo du point de comptage',
    'Coordonnées géographiques',
]
df21 = pd.read_csv("data/2021_comptage-velo-donnees-sites-comptage.csv", sep=";", usecols=colsToKeep, on_bad_lines='skip')
df21.head()
# Out:
#   Nom du point de comptage  Comptage horaire Date et heure de comptage  \
# 0   105 rue La Fayette E-O               0.0       2021-01-01T00:00:00
# 1   105 rue La Fayette E-O               1.0       2021-01-01T00:15:00
# 2   105 rue La Fayette E-O               1.0       2021-01-01T00:30:00
# 3   105 rue La Fayette E-O               0.0       2021-01-01T00:45:00
# 4   105 rue La Fayette E-O               2.0       2021-01-01T01:00:00
#
#   Coordonnées géographiques
# 0           48.87773,2.3506
# 1           48.87773,2.3506
# 2           48.87773,2.3506
# 3           48.87773,2.3506
# 4           48.87773,2.3506

# %%
df21.shape
# Out:
# (5851680, 4)

# %%
df21[['latitude', 'longitude']] = df21['Coordonnées géographiques'].str.split(',', n=1, expand=True)

df21["Date et heure de comptage"] = pd.to_datetime(
    df21["Date et heure de comptage"], 
    utc=True,    # rend les dates tz‑aware (UTC)
    errors='coerce'
)

# %%
df21_sortedbyplace = df21.sort_values(by=["Nom du point de comptage","Date et heure de comptage"])
df21_sortedbyplace.head()
# Out:
#                   Nom du point de comptage  Comptage horaire  \
# 210240  10 avenue de la Grande Armée SE-NO               0.0
# 210241  10 avenue de la Grande Armée SE-NO               0.0
# 210242  10 avenue de la Grande Armée SE-NO               0.0
# 210243  10 avenue de la Grande Armée SE-NO               0.0
# 210244  10 avenue de la Grande Armée SE-NO               0.0
#
#        Date et heure de comptage Coordonnées géographiques   latitude  \
# 210240 2021-01-01 00:00:00+00:00        48.874716,2.292439  48.874716
# 210241 2021-01-01 00:15:00+00:00        48.874716,2.292439  48.874716
# 210242 2021-01-01 00:30:00+00:00        48.874716,2.292439  48.874716
# 210243 2021-01-01 00:45:00+00:00        48.874716,2.292439  48.874716
# 210244 2021-01-01 01:00:00+00:00        48.874716,2.292439  48.874716
#
#        longitude
# 210240  2.292439
# 210241  2.292439
# 210242  2.292439
# 210243  2.292439
# 210244  2.292439

# %%
df21_sortedbyplace.shape
# Out:
# (5851680, 6)

# %%
cols = ["Nom du point de comptage", "Coordonnées géographiques", "latitude", "longitude"]
df21_sites = df21[cols].drop_duplicates(subset=["Nom du point de comptage"])
print(df21_sites.shape)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# 2102400                      48.83421,2.26542           48.83421
# 2137440                      48.83848,2.37587           48.83848
# 2172480                      48.86502,2.35387           48.86502
# 2207520                      48.86288,2.31179           48.86288
# 2242560                      48.85013,2.35423           48.85013
# 2277600                      48.84201,2.36729           48.84201
# 2312640                      48.86462,2.31444           48.86462
# 2347680                      48.86377,2.35096           48.86377
# 2382720                      48.84638,2.31529           48.84638
# 2417760                      48.88529,2.32666           48.88529
# 2452800                    48.860528,2.388364          48.860528
# 5361120                  48.8511307,2.3456784         48.8511307
# 5396160                      48.89683,2.34521           48.89683
# 5501280                      48.83977,2.30198           48.83977
# 5711520                      48.86357,2.32203           48.86357
#
#                   longitude
# 0                    2.3506
# 35040               2.33307
# 70080              2.383378
# 105120            2.3401251
# 140160             2.375456
# 175200              2.37376
# 210240             2.292439
# 245280              2.29215
# 280320              2.37407
# 315360              2.35535
# 350400   2.2815460310567834
# 385440              2.26733
# 420480             2.354926
# 455520              2.38886
# 490560             2.281203
# 525600             2.353199
# 560640              2.37305
# 595680              2.38409
# 630720             2.372279
# 665760              2.38465
# 700800             2.388364
# 735840              2.35348
# 770880              2.32014
# 805920              2.37472
# 840960             2.374872
# 876000              2.40932
# 911040             2.307419
# 946080              2.35902
# 981120                2.301
# 1016160              2.3592
# 1051200            2.307076
# 1086240             2.30115
# 1121280             2.31973
# 1156320             2.31061
# 1191360             2.32003
# 1226400            2.310345
# 1261440             2.32537
# 1296480           2.3432985
# 1331520           2.3456784
# 1366560            2.345648
# 1401600             2.34538
# 1436640             2.33338
# 1471680              2.3497
# 1506720            2.375429
# 1541760               2.377
# 1576800             2.35702
# 1611840             2.27586
# 1646880             2.38531
# 1681920           2.3688522
# 1716960             2.38699
# 1752000             2.30303
# 1787040             2.38482
# 1822080             2.26694
# 1857120            2.333233
# 1892160             2.35211
# 1927200   2.400550837519253
# 1962240             2.35953
# 1997280             2.40969
# 2032320             2.36811
# 2067360             2.28508
# 2102400             2.26542
# 2137440             2.37587
# 2172480             2.35387
# 2207520             2.31179
# 2242560             2.35423
# 2277600             2.36729
# 2312640             2.31444
# 2347680             2.35096
# 2382720             2.31529
# 2417760             2.32666
# 2452800            2.388364
# 5361120           2.3456784
# 5396160             2.34521
# 5501280             2.30198
# 5711520             2.32203

# %%
import geopandas as gpd

# 1. Copie du DataFrame de base
df = df21_sites.copy()

# 2. Nettoyage des coordonnées
df['latitude']  = pd.to_numeric(df['latitude'],  errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

df = df.dropna(subset=['latitude', 'longitude'])

# 3. Création d’un GeoDataFrame à partir du DataFrame nettoyé
gdf_sites = gpd.GeoDataFrame(
    df,
    geometry = gpd.points_from_xy(df.longitude, df.latitude),
    crs="EPSG:4326"
)

# 4. Chargement et projection des arrondissements
url_geojson = "https://opendata.paris.fr/explore/dataset/arrondissements/download/?format=geojson&timezone=Europe/Berlin&lang=fr"
gdf_arr = gpd.read_file(url_geojson)
gdf_arr = gdf_arr.to_crs(epsg=4326)

# 5. Spatial join — points dans les polygones
gdf_joined = gpd.sjoin(gdf_sites, gdf_arr, how="left", predicate="within")

# 6. Sélection & renommage des colonnes d’intérêt
df21_final = gdf_joined[
    ["Nom du point de comptage", "Coordonnées géographiques", "latitude", "longitude", "l_ar"]
].rename(columns={"l_ar": "arrondissement"})

df21_final
# Out:
#                                   Nom du point de comptage  \
# 0                                   105 rue La Fayette E-O
# 35040                   106 avenue Denfert Rochereau NE-SO
# 70080                           135 avenue Daumesnil SE-NO
# 105120                        158 rue de Rivoli (Voie Bus)
# 140160                            27 boulevard Diderot E-O
# 175200                         67 boulevard Voltaire SE-NO
# 210240                  10 avenue de la Grande Armée SE-NO
# 245280                   7 avenue de la Grande Armée NO-SE
# 280320                         72 boulevard Voltaire NO-SE
# 315360                       89 boulevard de Magenta NO-SE
# 350400                16 avenue de la Porte des Ternes E-O
# 385440                            Pont du Garigliano NO-SE
# 420480                      102 boulevard de Magenta SE-NO
# 455520                  26 boulevard de Ménilmontant SE-NO
# 490560       Face au 16 avenue de la  Porte des Ternes O-E
# 525600                  21 boulevard Auguste Blanqui SO-NE
# 560640                    72 boulevard Richard Lenoir  S-N
# 595680                                 Pont National SO-NE
# 630720                     77 boulevard Richard Lenoir N-S
# 665760                                Pont National  NE-SO
# 700800                  35 boulevard de Ménilmontant NO-SE
# 735840                  10 boulevard Auguste Blanqui NE-SO
# 770880                   243 boulevard Saint Germain NO-SE
# 805920                          87 avenue de Flandre NE-SO
# 840960                          72 avenue de Flandre SO-NE
# 876000                2 avenue de la Porte de Bagnolet O-E
# 911040                  44 avenue des Champs Elysées SE-NO
# 946080                             180 avenue d'Italie N-S
# 981120                              129 rue Lecourbe SO-NE
# 1016160                            147 avenue d'Italie S-N
# 1051200                 33 avenue des Champs Elysées NO-SE
# 1086240                             132 rue Lecourbe NE-SO
# 1121280                            Pont de la Concorde N-S
# 1156320                             Pont des Invalides S-N
# 1191360                            Pont de la Concorde S-N
# 1226400                             Pont des Invalides N-S
# 1261440  3 avenue de la Porte D'Orléans (gare routière)...
# 1296480                      21 boulevard Saint Michel S-N
# 1331520              30 rue Saint Jacques N-S (temporaire)
# 1366560                            74 Boulevard Ornano S-N
# 1401600               69 Boulevard Ornano N-S (temporaire)
# 1436640                        97 avenue Denfert Rochereau
# 1471680                                 100 rue La Fayette
# 1506720                               28 boulevard Diderot
# 1541760                           39 quai François Mauriac
# 1576800                        18 quai de l'Hôtel de Ville
# 1611840                              Voie Georges Pompidou
# 1646880                        Face au 48 quai de la marne
# 1681920                       Face 104 rue d'Aubervilliers
# 1716960                           Face au 70 quai de Bercy
# 1752000                                 6 rue Julia Bartet
# 1787040                          Face au 25 quai de l'Oise
# 1822080                                 Pont du Garigliano
# 1857120                      152 boulevard du Montparnasse
# 1892160                             Totem 64 Rue de Rivoli
# 1927200          Face au 8 avenue de la porte de Charenton
# 1962240                              72 rue de la Chapelle
# 1997280           Face au 4 avenue de la porte de Bagnolet
# 2032320                             Pont Charles De Gaulle
# 2067360                                36 quai de Grenelle
# 2102400                             Face au 40 quai D'Issy
# 2137440                                      Pont de Bercy
# 2172480                                     38 rue Turbigo
# 2172480      3ème Ardt
# 2207520      7ème Ardt
# 2242560      5ème Ardt
# 2277600     13ème Ardt
# 2312640      8ème Ardt
# 2347680      2ème Ardt
# 2382720     15ème Ardt
# 2417760     18ème Ardt
# 2452800     11ème Ardt
# 5361120      5ème Ardt
# 5396160     18ème Ardt
# 5501280     15ème Ardt
# 5711520       1er Ardt

# %%
import pandas as pd

def list_to_semicolon_str(lst):
    return "; ".join(str(v) for v in lst if pd.notna(v))

# Regroupement par arrondissement et concaténation des coordonnées
tableau_arr = (
    df21_final
    .groupby("arrondissement", dropna=False)
    .agg({
        "Coordonnées géographiques": lambda x: list_to_semicolon_str(x),
        "latitude": lambda x: list_to_semicolon_str(x),
        "longitude": lambda x: list_to_semicolon_str(x)
    })
    .reset_index()
)

# Trier les arrondissements par numéro — si le nom contient un nombre
# On extrait le premier nombre trouvé dans la chaîne (ex “12e”, “8”, etc.)
tableau_arr['arr_num'] = (
    tableau_arr['arrondissement']
    .str.extract(r'(\d+)', expand=False)  # capture les chiffres
    .astype(float, errors='ignore')       # convertit en float si possible
)

# Trier par ce numéro, en mettant les NaN (arrondissements sans numéro numérique) à la fin
tableau_arr = tableau_arr.sort_values(
    by='arr_num', na_position='last'
).drop(columns='arr_num').reset_index(drop=True)

# Optionnel : afficher tout, mais attention si le tableau est très long
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

tableau_arr
# Out:
#    arrondissement  \
# 0        1er Ardt
# 1       2ème Ardt
# 2       3ème Ardt
# 3       4ème Ardt
# 4       5ème Ardt
# 5       6ème Ardt
# 6       7ème Ardt
# 7       8ème Ardt
# 8      10ème Ardt
# 9      11ème Ardt
# 10     12ème Ardt
# 11     13ème Ardt
# 12     14ème Ardt
# 13     15ème Ardt
# 14     16ème Ardt
# 15     17ème Ardt
# 16     18ème Ardt
# 17     19ème Ardt
# 18     20ème Ardt
# 19            NaN
#
#                                                                                                                                           Coordonnées géographiques  \
# 0                                                                                                                            48.8611449,2.3401251; 48.86357,2.32203
# 1                                                                                                                                                  48.86377,2.35096
# 2                                                                                                                                                  48.86502,2.35387
# 3                                                                                                                                48.85372,2.35702; 48.85735,2.35211
# 4                                                                                 48.851525,2.3432985; 48.8511307,2.3456784; 48.85013,2.35423; 48.8511307,2.3456784
# 5                                                                                                                                                48.840801,2.333233
# 6                                                                                           48.86179,2.32014; 48.86282,2.31061; 48.86284,2.310345; 48.86288,2.31179
# 7                                                                      48.869873,2.307419; 48.869831,2.307076; 48.86373,2.31973; 48.86378,2.32003; 48.86462,2.31444
# 8                                                                                            48.87773,2.3506; 48.87756,2.35535; 48.877726,2.354926; 48.87813,2.3497
# 9                                                  48.86149,2.37376; 48.86155,2.37407; 48.86077,2.37305; 48.860852,2.372279; 48.860528,2.388364; 48.860528,2.388364
# 10                            48.843435,2.383378; 48.846099,2.375456; 48.846028,2.375429; 48.8295233,2.38699; 48.83033052177593,2.400550837519253; 48.83848,2.37587
# 11  48.830449,2.353199; 48.82658,2.38409; 48.82682,2.38465; 48.83068,2.35348; 48.82024,2.35902; 48.82026,2.3592; 48.83436,2.377; 48.84223,2.36811; 48.84201,2.36729
# %%
df21.shape
# Out:
# (5851680, 6)

# %%
df21["Date et heure de comptage"] = pd.to_datetime(df21["Date et heure de comptage"], utc=True)
df21["Date et heure de comptage"] = df21["Date et heure de comptage"].dt.tz_convert("Europe/Paris")
date_min = df21["Date et heure de comptage"].min()
date_max = df21["Date et heure de comptage"].max()

print("Date la plus ancienne :", date_min)
print("Date la plus récente :", date_max)
# Out:
# Date la plus ancienne : 2021-01-01 01:00:00+01:00
# Date la plus récente : 2022-01-01 00:45:00+01:00

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
ANNEE = 2021
START_DATE = "2021-01-01"
END_DATE   = "2021-12-31"

results_temp = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df21_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"📡 Récupération météo pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=apparent_temperature"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        temps  = data["hourly"].get("apparent_temperature", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, temp in zip(heures, temps):
            results_temp.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "temperature_apparente": temp
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df21_temp_horaire = pd.DataFrame(results_temp)

# Conversion datetime
df21_temp_horaire["datetime"] = pd.to_datetime(
    df21_temp_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df21_temp_horaire = df21_temp_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2021_temperature_horaire_par_site_comptage.csv"
)

df21_temp_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df21_temp_horaire.head(20))
# Out:
# 📡 Récupération météo pour : 105 rue La Fayette E-O
# 📡 Récupération météo pour : 106 avenue Denfert Rochereau NE-SO
# 📡 Récupération météo pour : 135 avenue Daumesnil SE-NO
# 📡 Récupération météo pour : 158 rue de Rivoli (Voie Bus)
# 📡 Récupération météo pour : 27 boulevard Diderot E-O
# 📡 Récupération météo pour : 67 boulevard Voltaire SE-NO
# 📡 Récupération météo pour : 10 avenue de la Grande Armée SE-NO
# 📡 Récupération météo pour : 7 avenue de la Grande Armée NO-SE
# 📡 Récupération météo pour : 72 boulevard Voltaire NO-SE
# 📡 Récupération météo pour : 89 boulevard de Magenta NO-SE
# 📡 Récupération météo pour : 16 avenue de la Porte des Ternes E-O
# 📡 Récupération météo pour : Pont du Garigliano NO-SE
# 📡 Récupération météo pour : 102 boulevard de Magenta SE-NO
# 📡 Récupération météo pour : 26 boulevard de Ménilmontant SE-NO
# 📡 Récupération météo pour : Face au 16 avenue de la  Porte des Ternes O-E
# 📡 Récupération météo pour : 21 boulevard Auguste Blanqui SO-NE
# 📡 Récupération météo pour : 72 boulevard Richard Lenoir  S-N
# 📡 Récupération météo pour : Pont National SO-NE
# 📡 Récupération météo pour : 77 boulevard Richard Lenoir N-S
# 📡 Récupération météo pour : Pont National  NE-SO
# 📡 Récupération météo pour : 35 boulevard de Ménilmontant NO-SE
# 📡 Récupération météo pour : 10 boulevard Auguste Blanqui NE-SO
# 📡 Récupération météo pour : 243 boulevard Saint Germain NO-SE
# 📡 Récupération météo pour : 87 avenue de Flandre NE-SO
# 📡 Récupération météo pour : 72 avenue de Flandre SO-NE
# 📡 Récupération météo pour : 2 avenue de la Porte de Bagnolet O-E
# 📡 Récupération météo pour : 44 avenue des Champs Elysées SE-NO
# 📡 Récupération météo pour : 180 avenue d'Italie N-S
# 📡 Récupération météo pour : 129 rue Lecourbe SO-NE
# 📡 Récupération météo pour : 147 avenue d'Italie S-N
# 📡 Récupération météo pour : 33 avenue des Champs Elysées NO-SE
# 📡 Récupération météo pour : 132 rue Lecourbe NE-SO
# 📡 Récupération météo pour : Pont de la Concorde N-S
# 📡 Récupération météo pour : Pont des Invalides S-N
# 📡 Récupération météo pour : Pont de la Concorde S-N
# 📡 Récupération météo pour : Pont des Invalides N-S
# 📡 Récupération météo pour : 3 avenue de la Porte D'Orléans (gare routière) S-N
# 📡 Récupération météo pour : 21 boulevard Saint Michel S-N
# 📡 Récupération météo pour : 30 rue Saint Jacques N-S (temporaire)
# 📡 Récupération météo pour : 74 Boulevard Ornano S-N
# 📡 Récupération météo pour : 69 Boulevard Ornano N-S (temporaire)
# 📡 Récupération météo pour : 97 avenue Denfert Rochereau
# 📡 Récupération météo pour : 100 rue La Fayette
# 📡 Récupération météo pour : 28 boulevard Diderot
# 📡 Récupération météo pour : 39 quai François Mauriac
# 📡 Récupération météo pour : 18 quai de l'Hôtel de Ville
# 📡 Récupération météo pour : Voie Georges Pompidou
# 📡 Récupération météo pour : Face au 48 quai de la marne
# 📡 Récupération météo pour : Face 104 rue d'Aubervilliers
# 📡 Récupération météo pour : Face au 70 quai de Bercy
# 📡 Récupération météo pour : 6 rue Julia Bartet
# 📡 Récupération météo pour : Face au 25 quai de l'Oise
# 📡 Récupération météo pour : Pont du Garigliano
# 📡 Récupération météo pour : 152 boulevard du Montparnasse
# 📡 Récupération météo pour : Totem 64 Rue de Rivoli
# 📡 Récupération météo pour : Face au 8 avenue de la porte de Charenton
# 📡 Récupération météo pour : 72 rue de la Chapelle
# 📡 Récupération météo pour : Face au 4 avenue de la porte de Bagnolet
# 📡 Récupération météo pour : Pont Charles De Gaulle
# 📡 Récupération météo pour : 36 quai de Grenelle
# 📡 Récupération météo pour : Face au 40 quai D'Issy
# 📡 Récupération météo pour : Pont de Bercy
# 📡 Récupération météo pour : 38 rue Turbigo
# 📡 Récupération météo pour : Quai d'Orsay
# 📡 Récupération météo pour : 27 quai de la Tournelle
# 📡 Récupération météo pour : Totem 85 quai d'Austerlitz
# 📡 Récupération météo pour : Totem Cours la Reine
# 📡 Récupération météo pour : Totem 73 boulevard de Sébastopol
# 📡 Récupération météo pour : 90 Rue De Sèvres
# 📡 Récupération météo pour : 20 Avenue de Clichy
# 📡 Récupération météo pour : 35 boulevard de Ménilmontant
# 📡 Récupération météo pour : 30 rue Saint Jacques N-S
# 📡 Récupération météo pour : 69 Boulevard Ornano N-S
# 📡 Récupération météo pour : 254 rue de Vaugirard
# 📡 Récupération météo pour : Quai des Tuileries
# ✅ Données sauvegardées dans data/2021_temperature_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  temperature_apparente
# 0  2021-01-01 00:00:00                   -6.0
# 1  2021-01-01 01:00:00                   -3.5
# 2  2021-01-01 02:00:00                   -4.9
# 3  2021-01-01 03:00:00                   -5.5
# 4  2021-01-01 04:00:00                   -5.1
# 5  2021-01-01 05:00:00                   -5.2
# 6  2021-01-01 06:00:00                   -5.6
# 7  2021-01-01 07:00:00                   -5.0
# 8  2021-01-01 08:00:00                   -4.2
# 9  2021-01-01 09:00:00                   -3.6
# 10 2021-01-01 10:00:00                   -2.8
# 11 2021-01-01 11:00:00                   -1.7
# 12 2021-01-01 12:00:00                   -0.5
# 13 2021-01-01 13:00:00                   -0.1
# 14 2021-01-01 14:00:00                    0.4
# 15 2021-01-01 15:00:00                    0.4
# 16 2021-01-01 16:00:00                    0.4
# 17 2021-01-01 17:00:00                   -0.5
# 18 2021-01-01 18:00:00                   -1.5
# 19 2021-01-01 19:00:00                   -2.3

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
ANNEE = 2021
START_DATE = "2021-01-01"
END_DATE   = "2021-12-31"

results_precip = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df21_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"🌧️ Récupération précipitations pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=precipitation"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        prec   = data["hourly"].get("precipitation", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, p in zip(heures, prec):
            results_precip.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "precipitation_mm": p
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df21_precip_horaire = pd.DataFrame(results_precip)

# Conversion datetime
df21_precip_horaire["datetime"] = pd.to_datetime(
    df21_precip_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df21_precip_horaire = df21_precip_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2021_precipitation_horaire_par_site_comptage.csv"
)

df21_precip_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df21_precip_horaire.head(20))
# Out:
# 🌧️ Récupération précipitations pour : 105 rue La Fayette E-O
# 🌧️ Récupération précipitations pour : 106 avenue Denfert Rochereau NE-SO
# 🌧️ Récupération précipitations pour : 135 avenue Daumesnil SE-NO
# 🌧️ Récupération précipitations pour : 158 rue de Rivoli (Voie Bus)
# 🌧️ Récupération précipitations pour : 27 boulevard Diderot E-O
# 🌧️ Récupération précipitations pour : 67 boulevard Voltaire SE-NO
# 🌧️ Récupération précipitations pour : 10 avenue de la Grande Armée SE-NO
# 🌧️ Récupération précipitations pour : 7 avenue de la Grande Armée NO-SE
# 🌧️ Récupération précipitations pour : 72 boulevard Voltaire NO-SE
# 🌧️ Récupération précipitations pour : 89 boulevard de Magenta NO-SE
# 🌧️ Récupération précipitations pour : 16 avenue de la Porte des Ternes E-O
# 🌧️ Récupération précipitations pour : Pont du Garigliano NO-SE
# 🌧️ Récupération précipitations pour : 102 boulevard de Magenta SE-NO
# 🌧️ Récupération précipitations pour : 26 boulevard de Ménilmontant SE-NO
# 🌧️ Récupération précipitations pour : Face au 16 avenue de la  Porte des Ternes O-E
# 🌧️ Récupération précipitations pour : 21 boulevard Auguste Blanqui SO-NE
# 🌧️ Récupération précipitations pour : 72 boulevard Richard Lenoir  S-N
# 🌧️ Récupération précipitations pour : Pont National SO-NE
# 🌧️ Récupération précipitations pour : 77 boulevard Richard Lenoir N-S
# 🌧️ Récupération précipitations pour : Pont National  NE-SO
# 🌧️ Récupération précipitations pour : 35 boulevard de Ménilmontant NO-SE
# 🌧️ Récupération précipitations pour : 10 boulevard Auguste Blanqui NE-SO
# 🌧️ Récupération précipitations pour : 243 boulevard Saint Germain NO-SE
# 🌧️ Récupération précipitations pour : 87 avenue de Flandre NE-SO
# 🌧️ Récupération précipitations pour : 72 avenue de Flandre SO-NE
# 🌧️ Récupération précipitations pour : 2 avenue de la Porte de Bagnolet O-E
# 🌧️ Récupération précipitations pour : 44 avenue des Champs Elysées SE-NO
# 🌧️ Récupération précipitations pour : 180 avenue d'Italie N-S
# 🌧️ Récupération précipitations pour : 129 rue Lecourbe SO-NE
# 🌧️ Récupération précipitations pour : 147 avenue d'Italie S-N
# 🌧️ Récupération précipitations pour : 33 avenue des Champs Elysées NO-SE
# 🌧️ Récupération précipitations pour : 132 rue Lecourbe NE-SO
# 🌧️ Récupération précipitations pour : Pont de la Concorde N-S
# 🌧️ Récupération précipitations pour : Pont des Invalides S-N
# 🌧️ Récupération précipitations pour : Pont de la Concorde S-N
# 🌧️ Récupération précipitations pour : Pont des Invalides N-S
# 🌧️ Récupération précipitations pour : 3 avenue de la Porte D'Orléans (gare routière) S-N
# 🌧️ Récupération précipitations pour : 21 boulevard Saint Michel S-N
# 🌧️ Récupération précipitations pour : 30 rue Saint Jacques N-S (temporaire)
# 🌧️ Récupération précipitations pour : 74 Boulevard Ornano S-N
# 🌧️ Récupération précipitations pour : 69 Boulevard Ornano N-S (temporaire)
# 🌧️ Récupération précipitations pour : 97 avenue Denfert Rochereau
# 🌧️ Récupération précipitations pour : 100 rue La Fayette
# 🌧️ Récupération précipitations pour : 28 boulevard Diderot
# 🌧️ Récupération précipitations pour : 39 quai François Mauriac
# 🌧️ Récupération précipitations pour : 18 quai de l'Hôtel de Ville
# 🌧️ Récupération précipitations pour : Voie Georges Pompidou
# 🌧️ Récupération précipitations pour : Face au 48 quai de la marne
# 🌧️ Récupération précipitations pour : Face 104 rue d'Aubervilliers
# 🌧️ Récupération précipitations pour : Face au 70 quai de Bercy
# 🌧️ Récupération précipitations pour : 6 rue Julia Bartet
# 🌧️ Récupération précipitations pour : Face au 25 quai de l'Oise
# 🌧️ Récupération précipitations pour : Pont du Garigliano
# 🌧️ Récupération précipitations pour : 152 boulevard du Montparnasse
# 🌧️ Récupération précipitations pour : Totem 64 Rue de Rivoli
# 🌧️ Récupération précipitations pour : Face au 8 avenue de la porte de Charenton
# 🌧️ Récupération précipitations pour : 72 rue de la Chapelle
# 🌧️ Récupération précipitations pour : Face au 4 avenue de la porte de Bagnolet
# 🌧️ Récupération précipitations pour : Pont Charles De Gaulle
# 🌧️ Récupération précipitations pour : 36 quai de Grenelle
# 🌧️ Récupération précipitations pour : Face au 40 quai D'Issy
# 🌧️ Récupération précipitations pour : Pont de Bercy
# 🌧️ Récupération précipitations pour : 38 rue Turbigo
# 🌧️ Récupération précipitations pour : Quai d'Orsay
# 🌧️ Récupération précipitations pour : 27 quai de la Tournelle
# 🌧️ Récupération précipitations pour : Totem 85 quai d'Austerlitz
# 🌧️ Récupération précipitations pour : Totem Cours la Reine
# 🌧️ Récupération précipitations pour : Totem 73 boulevard de Sébastopol
# 🌧️ Récupération précipitations pour : 90 Rue De Sèvres
# 🌧️ Récupération précipitations pour : 20 Avenue de Clichy
# 🌧️ Récupération précipitations pour : 35 boulevard de Ménilmontant
# 🌧️ Récupération précipitations pour : 30 rue Saint Jacques N-S
# 🌧️ Récupération précipitations pour : 69 Boulevard Ornano N-S
# 🌧️ Récupération précipitations pour : 254 rue de Vaugirard
# 🌧️ Récupération précipitations pour : Quai des Tuileries
# ✅ Données sauvegardées dans data/2021_precipitation_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  precipitation_mm
# 0  2021-01-01 00:00:00               0.0
# 1  2021-01-01 01:00:00               0.0
# 2  2021-01-01 02:00:00               0.0
# 3  2021-01-01 03:00:00               0.0
# 4  2021-01-01 04:00:00               0.0
# 5  2021-01-01 05:00:00               0.0
# 6  2021-01-01 06:00:00               0.0
# 7  2021-01-01 07:00:00               0.0
# 8  2021-01-01 08:00:00               0.0
# 9  2021-01-01 09:00:00               0.0
# 10 2021-01-01 10:00:00               0.0
# 11 2021-01-01 11:00:00               0.0
# 12 2021-01-01 12:00:00               0.0
# 13 2021-01-01 13:00:00               0.0
# 14 2021-01-01 14:00:00               0.0
# 15 2021-01-01 15:00:00               0.0
# 16 2021-01-01 16:00:00               0.0
# 17 2021-01-01 17:00:00               0.0
# 18 2021-01-01 18:00:00               0.0
# 19 2021-01-01 19:00:00               0.0

# %%
import requests
import pandas as pd
import os

# ===============================
# Paramètres généraux
# ===============================
START_DATE = "2021-01-01"
END_DATE   = "2021-12-31"

results_cloud = []

# ===============================
# Boucle sur chaque site de comptage
# ===============================
for _, row in df21_final.iterrows():

    nom_site = row["Nom du point de comptage"]
    arr      = row["arrondissement"]
    lat      = float(row["latitude"])
    lon      = float(row["longitude"])

    print(f"☁️ Récupération cloud_cover pour : {nom_site}")

    try:
        url = (
            "https://archive-api.open-meteo.com/v1/archive?"
            f"latitude={lat}&longitude={lon}"
            f"&start_date={START_DATE}&end_date={END_DATE}"
            "&hourly=cloud_cover"
            "&timezone=Europe/Paris"
        )

        resp = requests.get(url)
        resp.raise_for_status()
        data = resp.json()

        # Sécurité si données manquantes
        if "hourly" not in data:
            continue

        heures = data["hourly"].get("time", [])
        clouds = data["hourly"].get("cloud_cover", [])

        # ===============================
        # Création des lignes horaires
        # ===============================
        for dt, c in zip(heures, clouds):
            results_cloud.append({
                "nom_point_comptage": nom_site,
                "arrondissement": arr,
                "latitude": lat,
                "longitude": lon,
                "datetime": dt,
                "cloud_cover_pct": c
            })

    except Exception as e:
        print(f"❌ Erreur pour {nom_site} ({lat},{lon}) : {e}")

# ===============================
# DataFrame final
# ===============================
df21_cloud_horaire = pd.DataFrame(results_cloud)

# Conversion datetime
df21_cloud_horaire["datetime"] = pd.to_datetime(
    df21_cloud_horaire["datetime"],
    errors="coerce"
)

# Tri logique
df21_cloud_horaire = df21_cloud_horaire.sort_values(
    by=["nom_point_comptage", "datetime"]
).reset_index(drop=True)

# ===============================
# Sauvegarde locale
# ===============================
csv_path = os.path.join(
    "data",
    "2021_cloud_cover_horaire_par_site_comptage.csv"
)

df21_cloud_horaire.to_csv(csv_path, index=False)
print(f"✅ Données sauvegardées dans {csv_path}")

# ===============================
# Aperçu
# ===============================
with pd.option_context(
    'display.max_columns', None,
    'display.width', None
):
    print(df21_cloud_horaire.head(20))
# Out:
# ☁️ Récupération cloud_cover pour : 105 rue La Fayette E-O
# ☁️ Récupération cloud_cover pour : 106 avenue Denfert Rochereau NE-SO
# ☁️ Récupération cloud_cover pour : 135 avenue Daumesnil SE-NO
# ☁️ Récupération cloud_cover pour : 158 rue de Rivoli (Voie Bus)
# ☁️ Récupération cloud_cover pour : 27 boulevard Diderot E-O
# ☁️ Récupération cloud_cover pour : 67 boulevard Voltaire SE-NO
# ☁️ Récupération cloud_cover pour : 10 avenue de la Grande Armée SE-NO
# ☁️ Récupération cloud_cover pour : 7 avenue de la Grande Armée NO-SE
# ☁️ Récupération cloud_cover pour : 72 boulevard Voltaire NO-SE
# ☁️ Récupération cloud_cover pour : 89 boulevard de Magenta NO-SE
# ☁️ Récupération cloud_cover pour : 16 avenue de la Porte des Ternes E-O
# ☁️ Récupération cloud_cover pour : Pont du Garigliano NO-SE
# ☁️ Récupération cloud_cover pour : 102 boulevard de Magenta SE-NO
# ☁️ Récupération cloud_cover pour : 26 boulevard de Ménilmontant SE-NO
# ☁️ Récupération cloud_cover pour : Face au 16 avenue de la  Porte des Ternes O-E
# ☁️ Récupération cloud_cover pour : 21 boulevard Auguste Blanqui SO-NE
# ☁️ Récupération cloud_cover pour : 72 boulevard Richard Lenoir  S-N
# ☁️ Récupération cloud_cover pour : Pont National SO-NE
# ☁️ Récupération cloud_cover pour : 77 boulevard Richard Lenoir N-S
# ☁️ Récupération cloud_cover pour : Pont National  NE-SO
# ☁️ Récupération cloud_cover pour : 35 boulevard de Ménilmontant NO-SE
# ☁️ Récupération cloud_cover pour : 10 boulevard Auguste Blanqui NE-SO
# ☁️ Récupération cloud_cover pour : 243 boulevard Saint Germain NO-SE
# ☁️ Récupération cloud_cover pour : 87 avenue de Flandre NE-SO
# ☁️ Récupération cloud_cover pour : 72 avenue de Flandre SO-NE
# ☁️ Récupération cloud_cover pour : 2 avenue de la Porte de Bagnolet O-E
# ☁️ Récupération cloud_cover pour : 44 avenue des Champs Elysées SE-NO
# ☁️ Récupération cloud_cover pour : 180 avenue d'Italie N-S
# ☁️ Récupération cloud_cover pour : 129 rue Lecourbe SO-NE
# ☁️ Récupération cloud_cover pour : 147 avenue d'Italie S-N
# ☁️ Récupération cloud_cover pour : 33 avenue des Champs Elysées NO-SE
# ☁️ Récupération cloud_cover pour : 132 rue Lecourbe NE-SO
# ☁️ Récupération cloud_cover pour : Pont de la Concorde N-S
# ☁️ Récupération cloud_cover pour : Pont des Invalides S-N
# ☁️ Récupération cloud_cover pour : Pont de la Concorde S-N
# ☁️ Récupération cloud_cover pour : Pont des Invalides N-S
# ☁️ Récupération cloud_cover pour : 3 avenue de la Porte D'Orléans (gare routière) S-N
# ☁️ Récupération cloud_cover pour : 21 boulevard Saint Michel S-N
# ☁️ Récupération cloud_cover pour : 30 rue Saint Jacques N-S (temporaire)
# ☁️ Récupération cloud_cover pour : 74 Boulevard Ornano S-N
# ☁️ Récupération cloud_cover pour : 69 Boulevard Ornano N-S (temporaire)
# ☁️ Récupération cloud_cover pour : 97 avenue Denfert Rochereau
# ☁️ Récupération cloud_cover pour : 100 rue La Fayette
# ☁️ Récupération cloud_cover pour : 28 boulevard Diderot
# ☁️ Récupération cloud_cover pour : 39 quai François Mauriac
# ☁️ Récupération cloud_cover pour : 18 quai de l'Hôtel de Ville
# ☁️ Récupération cloud_cover pour : Voie Georges Pompidou
# ☁️ Récupération cloud_cover pour : Face au 48 quai de la marne
# ☁️ Récupération cloud_cover pour : Face 104 rue d'Aubervilliers
# ☁️ Récupération cloud_cover pour : Face au 70 quai de Bercy
# ☁️ Récupération cloud_cover pour : 6 rue Julia Bartet
# ☁️ Récupération cloud_cover pour : Face au 25 quai de l'Oise
# ☁️ Récupération cloud_cover pour : Pont du Garigliano
# ☁️ Récupération cloud_cover pour : 152 boulevard du Montparnasse
# ☁️ Récupération cloud_cover pour : Totem 64 Rue de Rivoli
# ☁️ Récupération cloud_cover pour : Face au 8 avenue de la porte de Charenton
# ☁️ Récupération cloud_cover pour : 72 rue de la Chapelle
# ☁️ Récupération cloud_cover pour : Face au 4 avenue de la porte de Bagnolet
# ☁️ Récupération cloud_cover pour : Pont Charles De Gaulle
# ☁️ Récupération cloud_cover pour : 36 quai de Grenelle
# ☁️ Récupération cloud_cover pour : Face au 40 quai D'Issy
# ☁️ Récupération cloud_cover pour : Pont de Bercy
# ☁️ Récupération cloud_cover pour : 38 rue Turbigo
# ☁️ Récupération cloud_cover pour : Quai d'Orsay
# ☁️ Récupération cloud_cover pour : 27 quai de la Tournelle
# ☁️ Récupération cloud_cover pour : Totem 85 quai d'Austerlitz
# ☁️ Récupération cloud_cover pour : Totem Cours la Reine
# ☁️ Récupération cloud_cover pour : Totem 73 boulevard de Sébastopol
# ☁️ Récupération cloud_cover pour : 90 Rue De Sèvres
# ☁️ Récupération cloud_cover pour : 20 Avenue de Clichy
# ☁️ Récupération cloud_cover pour : 35 boulevard de Ménilmontant
# ☁️ Récupération cloud_cover pour : 30 rue Saint Jacques N-S
# ☁️ Récupération cloud_cover pour : 69 Boulevard Ornano N-S
# ☁️ Récupération cloud_cover pour : 254 rue de Vaugirard
# ☁️ Récupération cloud_cover pour : Quai des Tuileries
# ✅ Données sauvegardées dans data/2021_cloud_cover_horaire_par_site_comptage.csv
#                     nom_point_comptage arrondissement   latitude  longitude  \
# 0   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 1   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 2   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 3   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 4   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 5   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 6   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 7   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 8   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 9   10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 10  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 11  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 12  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 13  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 14  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 15  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 16  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 17  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 18  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
# 19  10 avenue de la Grande Armée SE-NO     17ème Ardt  48.874716   2.292439
#
#               datetime  cloud_cover_pct
# 0  2021-01-01 00:00:00               12
# 1  2021-01-01 01:00:00               40
# 2  2021-01-01 02:00:00               25
# 3  2021-01-01 03:00:00               37
# 4  2021-01-01 04:00:00               44
# 5  2021-01-01 05:00:00               46
# 6  2021-01-01 06:00:00               67
# 7  2021-01-01 07:00:00               72
# 8  2021-01-01 08:00:00               87
# 9  2021-01-01 09:00:00               83
# 10 2021-01-01 10:00:00               54
# 11 2021-01-01 11:00:00               46
# 12 2021-01-01 12:00:00               51
# 13 2021-01-01 13:00:00               35
# 14 2021-01-01 14:00:00               83
# 15 2021-01-01 15:00:00               70
# 16 2021-01-01 16:00:00               53
# 17 2021-01-01 17:00:00               76
# 18 2021-01-01 18:00:00               52
# 19 2021-01-01 19:00:00               57
