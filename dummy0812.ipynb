# %%
import pandas as pd

# %%
df18 = pd.read_csv("data/2018_comptage-velo-donnees-compteurs.csv", on_bad_lines='skip')
df18.head()
# Out:
#                                                     Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques
# 100047547-104047547;6 rue Julia Bartet NE-SO;10...                                           2.303149
# 100047547-104047547;6 rue Julia Bartet NE-SO;10...                                           2.303149
# 100047547-104047547;6 rue Julia Bartet NE-SO;10...                                           2.303149
# 100047547-104047547;6 rue Julia Bartet NE-SO;10...                                           2.303149
# 100047547-104047547;6 rue Julia Bartet NE-SO;10...                                           2.303149

# %%
df18.shape
# Out:
# (157825, 1)

# %%
df19 = pd.read_csv("data/2019_comptage-velo-donnees-compteurs-2.csv", on_bad_lines='skip')
df19.head()
# Out:
#                                                     Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques
# 100047539-SC;21 Boulevard Auguste Blanqui SO-NE...                                           2.353199
# 100047539-SC;21 Boulevard Auguste Blanqui SO-NE...                                           2.353199
# 100047539-SC;21 Boulevard Auguste Blanqui SO-NE...                                           2.353199
# 100047539-SC;21 Boulevard Auguste Blanqui SO-NE...                                           2.353199
# 100047539-SC;21 Boulevard Auguste Blanqui SO-NE...                                           2.353199

# %%
df20 = pd.read_csv("data/2020_comptage-velo-donnees-compteurs-3.csv", on_bad_lines='skip')
df20.head()
# Out:
#                                                     Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques
# 100003096-353242251;97 avenue Denfert Rochereau...                                            2.33338
# 100003096-353242251;97 avenue Denfert Rochereau...                                            2.33338
# 100003096-353242251;97 avenue Denfert Rochereau...                                            2.33338
# 100003096-353242251;97 avenue Denfert Rochereau...                                            2.33338
# 100003096-353242251;97 avenue Denfert Rochereau...                                            2.33338

# %%
df21 = pd.read_csv("data/2021_comptage-velo-donnees-compteurs-4.csv", on_bad_lines='skip')
df21.head()
# Out:
#                                                     Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques
# 100003097-SC;105 rue La Fayette E-O;100003097;1...                                             2.3506
# 100003097-SC;105 rue La Fayette E-O;100003097;1...                                             2.3506
# 100003097-SC;105 rue La Fayette E-O;100003097;1...                                             2.3506
# 100003097-SC;105 rue La Fayette E-O;100003097;1...                                             2.3506
# 100003097-SC;105 rue La Fayette E-O;100003097;1...                                             2.3506

# %%
df22 = pd.read_csv("data/2022_comptage-velo-donnees-compteurs-5.csv", on_bad_lines='skip')
df22.head()
# Out:
#                                                     Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques
# 101003096-100003096;97 avenue Denfert Rochereau...                                            2.33314
# 101003096-100003096;97 avenue Denfert Rochereau...                                            2.33314
# 101003096-100003096;97 avenue Denfert Rochereau...                                            2.33314
# 101003096-100003096;97 avenue Denfert Rochereau...                                            2.33314
# 101003096-100003096;97 avenue Denfert Rochereau...                                            2.33314

# %%
df23 = pd.read_csv("data/2023_comptage-velo-donnees-compteurs-6.csv", on_bad_lines='skip')
df23.head()
# Out:
#    Identifiant du point de comptage Nom du point de comptage  \
# 0                         100003097       105 rue La Fayette
# 1                         100003097       105 rue La Fayette
# 2                         100003097       105 rue La Fayette
# 3                         100003097       105 rue La Fayette
# 4                         100003097       105 rue La Fayette
#
#    Comptage horaire Date et heure de comptage  \
# 0                 0   2023-06-09 04:30:00.000
# 1                 0   2023-04-08 09:30:00.000
# 2                 0   2023-04-08 02:45:00.000
# 3                 0   2023-05-26 23:30:00.000
# 4                 0   2023-05-26 01:00:00.000
#
#                 Lien vers photo du point de comptage Coordonnées géographiques
# 0  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# 1  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# 2  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# ...

# %%
df24 = pd.read_csv("data/2024_comptage-velo-donnees-compteurs-7.csv", on_bad_lines='skip')
df24.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                      Identifiant du compteur;"Nom du compteur";"Identifiant du site de comptage";"Nom du site de comptage";"Comptage horaire";"Date et heure de comptage";"Date d'installation du site de comptage";"Lien vers photo du site de comptage";"Coordonnées géographiques"
# ...

# %%
df25 = pd.read_csv("data/2025_comptage-velo-donnees-compteurs-8.csv", on_bad_lines='skip')
df25.head()
# Out:
#                                                    Identifiant du compteur;Nom du compteur;Identifiant du site de comptage;Nom du site de comptage;Comptage horaire;Date et heure de comptage;Date d'installation du site de comptage;Lien vers photo du site de comptage;Coordonnées géographiques;Identifiant technique compteur;ID Photos;test_lien_vers_photos_du_site_de_comptage_;id_photo_1;url_sites;type_dimage;mois_annee_comptage
# 100003098-101003098;106 avenue Denfert Rocherea...   2.33305;Y2H20114504;https://filer.eco-counter...
# 100003098-101003098;106 avenue Denfert Rocherea...   2.33305;Y2H20114504;https://filer.eco-counter...
# 100003098-101003098;106 avenue Denfert Rocherea...   2.33305;Y2H20114504;https://filer.eco-counter...
# 100003098-101003098;106 avenue Denfert Rocherea...   2.33305;Y2H20114504;https://filer.eco-counter...
# 100003098-101003098;106 avenue Denfert Rocherea...   2.33305;Y2H20114504;https://filer.eco-counter...

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df18 = pd.read_csv('data/2018_comptage-velo-donnees-compteurs.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df18.head()
# Out:
#   Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0      6 rue Julia Bartet                 4  2018-11-29T01:00:00+01:00
# 1      6 rue Julia Bartet                30  2018-11-29T22:00:00+01:00
# 2      6 rue Julia Bartet               116  2018-11-30T17:00:00+01:00
# 3      6 rue Julia Bartet                 0  2018-12-03T01:00:00+01:00
# 4      6 rue Julia Bartet                18  2018-12-03T11:00:00+01:00
#
#   Coordonnées géographiques
# 0         48.82648,2.303149
# 1         48.82648,2.303149
# 2         48.82648,2.303149
# 3         48.82648,2.303149
# 4         48.82648,2.303149

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df19 = pd.read_csv('data/2019_comptage-velo-donnees-compteurs-2.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df19.head()
# Out:
#               Nom du site de comptage  Comptage horaire  \
# 0  21 Boulevard Auguste Blanqui SO-NE                 0
# 1  21 Boulevard Auguste Blanqui SO-NE                31
# 2  21 Boulevard Auguste Blanqui SO-NE                24
# 3  21 Boulevard Auguste Blanqui SO-NE                 2
# 4  21 Boulevard Auguste Blanqui SO-NE                 0
#
#    Date et heure de comptage Coordonnées géographiques
# 0  2019-01-01T07:00:00+01:00        48.830449,2.353199
# 1  2019-01-02T18:00:00+01:00        48.830449,2.353199
# 2  2019-01-03T16:00:00+01:00        48.830449,2.353199
# 3  2019-01-04T04:00:00+01:00        48.830449,2.353199
# 4  2019-01-04T08:00:00+01:00        48.830449,2.353199

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df20 = pd.read_csv('data/2020_comptage-velo-donnees-compteurs-3.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df20.head()
# Out:
#        Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0  97 avenue Denfert Rochereau              12.0  2020-01-01T01:00:00+01:00
# 1  97 avenue Denfert Rochereau              11.0  2020-01-01T03:00:00+01:00
# 2  97 avenue Denfert Rochereau               6.0  2020-01-01T00:00:00+01:00
# 3  97 avenue Denfert Rochereau               9.0  2020-01-01T02:00:00+01:00
# 4  97 avenue Denfert Rochereau               6.0  2020-01-01T05:00:00+01:00
#
#   Coordonnées géographiques
# 0          48.83511,2.33338
# 1          48.83511,2.33338
# 2          48.83511,2.33338
# 3          48.83511,2.33338
# 4          48.83511,2.33338

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df21 = pd.read_csv('data/2021_comptage-velo-donnees-compteurs-4.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df21.head()
# Out:
#   Nom du site de comptage  Comptage horaire Date et heure de comptage  \
# 0  105 rue La Fayette E-O               2.0       2021-01-01T00:00:00
# 1  105 rue La Fayette E-O               3.0       2021-01-01T01:00:00
# 2  105 rue La Fayette E-O               1.0       2021-01-01T02:00:00
# 3  105 rue La Fayette E-O               5.0       2021-01-01T03:00:00
# 4  105 rue La Fayette E-O               6.0       2021-01-01T04:00:00
#
#   Coordonnées géographiques
# 0           48.87773,2.3506
# 1           48.87773,2.3506
# 2           48.87773,2.3506
# 3           48.87773,2.3506
# 4           48.87773,2.3506

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df22 = pd.read_csv('data/2022_comptage-velo-donnees-compteurs-5.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df22.head()
# Out:
#        Nom du site de comptage  Comptage horaire Date et heure de comptage  \
# 0  97 avenue Denfert Rochereau                 0       2022-01-01T00:00:00
# 1  97 avenue Denfert Rochereau                13       2022-01-01T01:00:00
# 2  97 avenue Denfert Rochereau                 9       2022-01-01T02:00:00
# 3  97 avenue Denfert Rochereau                12       2022-01-01T03:00:00
# 4  97 avenue Denfert Rochereau                10       2022-01-01T04:00:00
#
#   Coordonnées géographiques
# 0          48.83504,2.33314
# 1          48.83504,2.33314
# 2          48.83504,2.33314
# 3          48.83504,2.33314
# 4          48.83504,2.33314

# %%
list(df23.columns)
# Out:
# ['Identifiant du point de comptage',
#  'Nom du point de comptage',
#  'Comptage horaire',
#  'Date et heure de comptage',
#  'Lien vers photo du point de comptage',
#  'Coordonnées géographiques']

# %%
import pandas as pd

df_raw = pd.read_csv(
    "data/2023_comptage-velo-donnees-compteurs-6.csv",
    header=None,
    nrows=5,
    sep=None,                   # autodetection du séparateur
    engine='python'
)

df_raw
# Out:
#                                   0                         1  \
# 0  Identifiant du point de comptage  Nom du point de comptage
# 1                         100003097        105 rue La Fayette
# 2                         100003097        105 rue La Fayette
# 3                         100003097        105 rue La Fayette
# 4                         100003097        105 rue La Fayette
#
#                   2                          3  \
# 0  Comptage horaire  Date et heure de comptage
# 1                 0    2023-06-09 04:30:00.000
# 2                 0    2023-04-08 09:30:00.000
# 3                 0    2023-04-08 02:45:00.000
# 4                 0    2023-05-26 23:30:00.000
#
#                                                    4  \
# 0               Lien vers photo du point de comptage
# 1  ['https://filer.eco-counter-tools.com/file/23/...
# 2  ['https://filer.eco-counter-tools.com/file/23/...
# 3  ['https://filer.eco-counter-tools.com/file/23/...
# ...

# %%
# Lecture avec autodétection du séparateur
df23bis = pd.read_csv(
    "data/2023_comptage-velo-donnees-compteurs-6.csv",
    sep=None,
    engine='python'
)

# Garder uniquement les colonnes que tu veux
colsToKeep = [
    "Identifiant du point de comptage",
    "Nom du point de comptage",
    "Comptage horaire",
    "Date et heure de comptage",
    "Lien vers photo du point de comptage",
    "Coordonnées géographiques"
]

# Renommer les colonnes (elles sont actuellement en 0,1,2,...)
df23bis.columns = colsToKeep

# Filtrer les lignes de header parasites éventuelles
df23bis = df23bis[df23bis["Nom du point de comptage"] != "Nom du point de comptage"]


df23bis.head()
# Out:
#    Identifiant du point de comptage Nom du point de comptage  \
# 0                         100003097       105 rue La Fayette
# 1                         100003097       105 rue La Fayette
# 2                         100003097       105 rue La Fayette
# 3                         100003097       105 rue La Fayette
# 4                         100003097       105 rue La Fayette
#
#    Comptage horaire Date et heure de comptage  \
# 0                 0   2023-06-09 04:30:00.000
# 1                 0   2023-04-08 09:30:00.000
# 2                 0   2023-04-08 02:45:00.000
# 3                 0   2023-05-26 23:30:00.000
# 4                 0   2023-05-26 01:00:00.000
#
#                 Lien vers photo du point de comptage Coordonnées géographiques
# 0  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# 1  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# 2  ['https://filer.eco-counter-tools.com/file/23/...      4.887773E1, 2.3506E0
# ...

# %%
# Supprimer deux colonnes
df23bis = df23bis.drop(columns=[
    "Identifiant du point de comptage",
    "Lien vers photo du point de comptage"
])

# Renommer une colonne
df23bis = df23bis.rename(columns={
    "Nom du point de comptage": "Nom du site de comptage"
})

df23bis.head()
# Out:
#   Nom du site de comptage  Comptage horaire Date et heure de comptage  \
# 0      105 rue La Fayette                 0   2023-06-09 04:30:00.000
# 1      105 rue La Fayette                 0   2023-04-08 09:30:00.000
# 2      105 rue La Fayette                 0   2023-04-08 02:45:00.000
# 3      105 rue La Fayette                 0   2023-05-26 23:30:00.000
# 4      105 rue La Fayette                 0   2023-05-26 01:00:00.000
#
#   Coordonnées géographiques
# 0      4.887773E1, 2.3506E0
# 1      4.887773E1, 2.3506E0
# 2      4.887773E1, 2.3506E0
# 3      4.887773E1, 2.3506E0
# 4      4.887773E1, 2.3506E0

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df24 = pd.read_csv('data/2024_comptage-velo-donnees-compteurs-7.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df24.head()
# Out:
#   Nom du site de comptage  Comptage horaire      Date et heure de comptage  \
# 0   67 boulevard Voltaire             155.0  2024-01-02 19:00:00.000 +0100
# 1   67 boulevard Voltaire             169.0  2024-01-05 14:00:00.000 +0100
# 2   67 boulevard Voltaire              30.0  2024-01-09 06:00:00.000 +0100
# 3   67 boulevard Voltaire             294.0  2024-01-10 18:00:00.000 +0100
# 4   67 boulevard Voltaire               9.0  2024-01-12 04:00:00.000 +0100
#
#   Coordonnées géographiques
# 0         48.86149, 2.37376
# 1         48.86149, 2.37376
# 2         48.86149, 2.37376
# 3         48.86149, 2.37376
# 4         48.86149, 2.37376

# %%
colsToKeep = [
    # 'Identifiant du compteur',
    # 'Nom du compteur',
    # 'Identifiant du site de comptage',
    'Nom du site de comptage',
    'Comptage horaire',
    'Date et heure de comptage',
    #"Date d'installation du site de comptage",
    #'Lien vers photo du site de comptage',
    'Coordonnées géographiques',
    # 'Identifiant technique compteur',
    # 'ID Photos',
    # 'test_lien_vers_photos_du_site_de_comptage_',
    # 'id_photo_1',
    # 'url_sites',
    # 'type_dimage',
    # 'mois_annee_comptage'
]
df25 = pd.read_csv('data/2025_comptage-velo-donnees-compteurs-8.csv', sep=";", usecols=colsToKeep, on_bad_lines='skip')
df25.head()
# Out:
#         Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0  106 avenue Denfert Rochereau                 0  2024-11-01T06:00:00+01:00
# 1  106 avenue Denfert Rochereau                 0  2024-11-01T04:00:00+01:00
# 2  106 avenue Denfert Rochereau                 0  2024-11-01T07:00:00+01:00
# 3  106 avenue Denfert Rochereau                 0  2024-11-01T08:00:00+01:00
# 4  106 avenue Denfert Rochereau                 0  2024-11-01T05:00:00+01:00
#
#   Coordonnées géographiques
# 0         48.83507, 2.33305
# 1         48.83507, 2.33305
# 2         48.83507, 2.33305
# 3         48.83507, 2.33305
# 4         48.83507, 2.33305

# %%
# Liste de tous les DataFrames à fusionner
dfs = [df18, df19, df20, df21, df22, df23bis, df24, df25]

# Fusionner tous les DataFrames en un seul
df_all = pd.concat(dfs, ignore_index=True)

# Vérifier le résultat
df_all.head()
# Out:
#   Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0      6 rue Julia Bartet               4.0  2018-11-29T01:00:00+01:00
# 1      6 rue Julia Bartet              30.0  2018-11-29T22:00:00+01:00
# 2      6 rue Julia Bartet             116.0  2018-11-30T17:00:00+01:00
# 3      6 rue Julia Bartet               0.0  2018-12-03T01:00:00+01:00
# 4      6 rue Julia Bartet              18.0  2018-12-03T11:00:00+01:00
#
#   Coordonnées géographiques
# 0         48.82648,2.303149
# 1         48.82648,2.303149
# 2         48.82648,2.303149
# 3         48.82648,2.303149
# 4         48.82648,2.303149

# %%
df_all.shape  # pour voir combien de lignes et de colonnes
# Out:
# (9875584, 4)

# %%
# Séparer latitude et longitude
df_all[['latitude', 'longitude']] = df_all['Coordonnées géographiques'].str.split(',', n=1, expand=True)

df_all["Date et heure de comptage"] = pd.to_datetime(
    df_all["Date et heure de comptage"], 
    utc=True,    # rend les dates tz‑aware (UTC)
    errors='coerce'
)

# %%
df_all.head()
# Out:
#   Nom du site de comptage  Comptage horaire Date et heure de comptage  \
# 0      6 rue Julia Bartet               4.0 2018-11-29 00:00:00+00:00
# 1      6 rue Julia Bartet              30.0 2018-11-29 21:00:00+00:00
# 2      6 rue Julia Bartet             116.0 2018-11-30 16:00:00+00:00
# 3      6 rue Julia Bartet               0.0 2018-12-03 00:00:00+00:00
# 4      6 rue Julia Bartet              18.0 2018-12-03 10:00:00+00:00
#
#   Coordonnées géographiques  latitude longitude
# 0         48.82648,2.303149  48.82648  2.303149
# 1         48.82648,2.303149  48.82648  2.303149
# 2         48.82648,2.303149  48.82648  2.303149
# 3         48.82648,2.303149  48.82648  2.303149
# 4         48.82648,2.303149  48.82648  2.303149

# %%
df_all.shape
# Out:
# (9875584, 6)

# %%
df_all_sortedbyplace = df_all.sort_values(by=["Nom du site de comptage","Date et heure de comptage"])
df_all.head()
# Out:
#   Nom du site de comptage  Comptage horaire Date et heure de comptage  \
# 0      6 rue Julia Bartet               4.0 2018-11-29 00:00:00+00:00
# 1      6 rue Julia Bartet              30.0 2018-11-29 21:00:00+00:00
# 2      6 rue Julia Bartet             116.0 2018-11-30 16:00:00+00:00
# 3      6 rue Julia Bartet               0.0 2018-12-03 00:00:00+00:00
# 4      6 rue Julia Bartet              18.0 2018-12-03 10:00:00+00:00
#
#   Coordonnées géographiques  latitude longitude
# 0         48.82648,2.303149  48.82648  2.303149
# 1         48.82648,2.303149  48.82648  2.303149
# 2         48.82648,2.303149  48.82648  2.303149
# 3         48.82648,2.303149  48.82648  2.303149
# 4         48.82648,2.303149  48.82648  2.303149

# %%
df_all.shape
# Out:
# (9875584, 6)

# %%
cols = ["Nom du site de comptage", "Coordonnées géographiques", "latitude", "longitude"]
df_all_sites = df_all[cols].drop_duplicates(subset=["Nom du site de comptage"])
print(df_all_sites.shape)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df_all_sites
# Out:
# (187, 4)
#                                    Nom du site de comptage  \
# 0                                       6 rue Julia Bartet
# 22                                face au 70 Quai de Bercy
# 135                               77 Bd Richard Lenoir N-S
# 170                           Face 104 Rue d'Aubervilliers
# 240                              Face au 25 quai de l'Oise
# 325                     35 Boulevard de Menilmontant NO-SE
# 362                                   Pont National  NE-SO
# 392                             135 Avenue Daumesnil SE-NO
# 864                                   28 Boulevard Diderot
# 1147                                100 Rue La Fayette O-E
# 1575                    106 Avenue Denfert Rochereau NE-SO
# 2122                     243 Boulevard Saint Germain NO-SE
# 3852                           Face au 48 quai de la marne
# 3935                     7 Avenue de la Grande Armée NO-SE
# 4011                             72 Bd Richard Lenoir  S-N
# ...

# %%
import geopandas as gpd

# 1. Copie du DataFrame de base
df = df_all_sites.copy()

# 2. Nettoyage des coordonnées
df['latitude']  = pd.to_numeric(df['latitude'],  errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

df = df.dropna(subset=['latitude', 'longitude'])

# 3. Création d’un GeoDataFrame à partir du DataFrame nettoyé
gdf_sites = gpd.GeoDataFrame(
    df,
    geometry = gpd.points_from_xy(df.longitude, df.latitude),
    crs="EPSG:4326"
)

# 4. Chargement et projection des arrondissements
url_geojson = "https://opendata.paris.fr/explore/dataset/arrondissements/download/?format=geojson&timezone=Europe/Berlin&lang=fr"
gdf_arr = gpd.read_file(url_geojson)
gdf_arr = gdf_arr.to_crs(epsg=4326)

# 5. Spatial join — points dans les polygones
gdf_joined = gpd.sjoin(gdf_sites, gdf_arr, how="left", predicate="within")

# 6. Sélection & renommage des colonnes d’intérêt
df_all_final = gdf_joined[
    ["Nom du site de comptage", "Coordonnées géographiques", "latitude", "longitude", "l_ar"]
].rename(columns={"l_ar": "arrondissement"})

df_all_final
# Out:
#                                    Nom du site de comptage  \
# 0                                       6 rue Julia Bartet
# 22                                face au 70 Quai de Bercy
# 135                               77 Bd Richard Lenoir N-S
# 170                           Face 104 Rue d'Aubervilliers
# 240                              Face au 25 quai de l'Oise
# 325                     35 Boulevard de Menilmontant NO-SE
# 362                                   Pont National  NE-SO
# 392                             135 Avenue Daumesnil SE-NO
# 864                                   28 Boulevard Diderot
# 1147                                100 Rue La Fayette O-E
# 1575                    106 Avenue Denfert Rochereau NE-SO
# 2122                     243 Boulevard Saint Germain NO-SE
# 3852                           Face au 48 quai de la marne
# 3935                     7 Avenue de la Grande Armée NO-SE
# 4011                             72 Bd Richard Lenoir  S-N
# ...

# %%
import pandas as pd

def list_to_semicolon_str(lst):
    return "; ".join(str(v) for v in lst if pd.notna(v))

# Regroupement par arrondissement et concaténation des coordonnées
tableau_arr = (
    df_all_final
    .groupby("arrondissement", dropna=False)
    .agg({
        "Coordonnées géographiques": lambda x: list_to_semicolon_str(x),
        "latitude": lambda x: list_to_semicolon_str(x),
        "longitude": lambda x: list_to_semicolon_str(x)
    })
    .reset_index()
)

# Trier les arrondissements par numéro — si le nom contient un nombre
# On extrait le premier nombre trouvé dans la chaîne (ex “12e”, “8”, etc.)
tableau_arr['arr_num'] = (
    tableau_arr['arrondissement']
    .str.extract(r'(\d+)', expand=False)  # capture les chiffres
    .astype(float, errors='ignore')       # convertit en float si possible
)

# Trier par ce numéro, en mettant les NaN (arrondissements sans numéro numérique) à la fin
tableau_arr = tableau_arr.sort_values(
    by='arr_num', na_position='last'
).drop(columns='arr_num').reset_index(drop=True)

# Optionnel : afficher tout, mais attention si le tableau est très long
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

tableau_arr
# Out:
#    arrondissement  \
# 0        1er Ardt
# 1       2ème Ardt
# 2       3ème Ardt
# 3       4ème Ardt
# 4       5ème Ardt
# 5       6ème Ardt
# 6       7ème Ardt
# 7       8ème Ardt
# 8      10ème Ardt
# 9      11ème Ardt
# 10     12ème Ardt
# 11     13ème Ardt
# 12     14ème Ardt
# 13     15ème Ardt
# 14     16ème Ardt
# 15     17ème Ardt
# 16     18ème Ardt
# 17     19ème Ardt
# 18     20ème Ardt
# 19            NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                       Coordonnées géographiques  \
# ...

# %%
# Affiche l'ordre des clés de groupe pour df_all_final
grouped = df_all_final.groupby("arrondissement")
print("Order of groups (arrondissements):")
for arr, grp in grouped:
    print(arr)
# Out:
# Order of groups (arrondissements):
# 10ème Ardt
# 11ème Ardt
# 12ème Ardt
# 13ème Ardt
# 14ème Ardt
# 15ème Ardt
# 16ème Ardt
# 17ème Ardt
# 18ème Ardt
# 19ème Ardt
# 1er Ardt
# 20ème Ardt
# 2ème Ardt
# 3ème Ardt
# 4ème Ardt
# 5ème Ardt
# 6ème Ardt
# 7ème Ardt
# 8ème Ardt

# %%
for arr, grp in grouped:
    print(f"{arr} — {len(grp)} lignes")
# Out:
# 10ème Ardt — 10 lignes
# 11ème Ardt — 14 lignes
# 12ème Ardt — 16 lignes
# 13ème Ardt — 22 lignes
# 14ème Ardt — 15 lignes
# 15ème Ardt — 15 lignes
# 16ème Ardt — 7 lignes
# 17ème Ardt — 11 lignes
# 18ème Ardt — 11 lignes
# 19ème Ardt — 13 lignes
# 1er Ardt — 2 lignes
# 20ème Ardt — 11 lignes
# 2ème Ardt — 1 lignes
# 3ème Ardt — 1 lignes
# 4ème Ardt — 3 lignes
# 5ème Ardt — 8 lignes
# 6ème Ardt — 2 lignes
# 7ème Ardt — 13 lignes
# 8ème Ardt — 9 lignes

# %%
import requests
import pandas as pd
import calendar
import os
import time

def dernier_jour_du_mois(annee, mois):
    return calendar.monthrange(annee, mois)[1]

def list_mois(start_annee, end_annee):
    # génère une liste de périodes “YYYY-MM” entre start_annee-01 et end_annee-12
    months = []
    for an in range(start_annee, end_annee + 1):
        for m in range(1, 13):
            months.append(f"{an}-{m:02d}")
    return months

# Exemple : période de 2018 à 2025
mois = list_mois(2018, 2025)

results_temp = []

# Pour limiter le nombre d'appels trop rapides
DELAY_BETWEEN_REQUESTS = 1.0  # en secondes, ajuste selon besoin

for arr, df_arr in df_all_final.groupby("arrondissement"):
    lignes_arr = {"arrondissement": arr}

    for periode in mois:
        an, m = map(int, periode.split("-"))
        start = f"{an}-{m:02d}-01"
        end   = f"{an}-{m:02d}-{dernier_jour_du_mois(an,m)}"

        toutes_temp = []

        for _, row in df_arr.iterrows():
            lat = float(row["latitude"])
            lon = float(row["longitude"])

            # Construire l’URL
            url = (
                f"https://archive-api.open-meteo.com/v1/archive"
                f"?latitude={lat}&longitude={lon}"
                f"&start_date={start}&end_date={end}"
                "&hourly=apparent_temperature"
                "&timezone=Europe/Paris"
            )
            try:
                resp = requests.get(url, timeout=30)
                resp.raise_for_status()
                data = resp.json()

                temps = data.get("hourly", {}).get("apparent_temperature")
                if temps:
                    toutes_temp.extend(temps)
            except Exception as e:
                print(f"Erreur pour {arr}, {periode}, site {lat},{lon} : {e}")

            time.sleep(DELAY_BETWEEN_REQUESTS)  # pause pour éviter de surcharger l’API

        # si on a au moins une valeur, calcul moyenne
        lignes_arr[periode] = (sum(toutes_temp)/len(toutes_temp)) if toutes_temp else None

    results_temp.append(lignes_arr)

df_all_temp_mensuel = pd.DataFrame(results_temp)

df_all_temp_mensuel["arr_num"] = df_all_temp_mensuel["arrondissement"].str.extract(r"(\d+)").astype(float, errors='ignore')
df_all_temp_mensuel = df_all_temp_mensuel.sort_values("arr_num", na_position='last').drop(columns="arr_num").reset_index(drop=True)

# Sauvegarde dans ton dossier data
output_dir = "data"
os.makedirs(output_dir, exist_ok=True)
csv_path = os.path.join(output_dir, "temperature_par_arrondissement_mensuel_2018_2025.csv")
df_temp_mensuel.to_csv(csv_path, index=False)
print(f"✅ Données météo sauvegardées dans {csv_path}")

# Afficher le résultat
with pd.option_context('display.max_columns', None, 'display.width', None):
    print(df_temp_mensuel)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 59
#      56     except Exception as e:
#      57         print(f"Erreur pour {arr}, {periode}, site {lat},{lon} : {e}")
# ---> 59     time.sleep(DELAY_BETWEEN_REQUESTS)  # pause pour éviter de surcharger l’API
#      61 # si on a au moins une valeur, calcul moyenne
#      62 lignes_arr[periode] = (sum(toutes_temp)/len(toutes_temp)) if toutes_temp else None
#
# KeyboardInterrupt:
